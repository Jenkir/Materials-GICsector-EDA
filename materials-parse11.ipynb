# %%
# see https://towardsdatascience.com/how-do-i-extract-nested-data-in-python-4e7bed37566a

# %%
import pandas as pd
import requests
import json
from config import api_key
from pandas import json_normalize
import os

# %%
# pretty print the JSON
from pprint import pprint

pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 100)
# use below code to see full text of the columns; by providing None as the 2nd parameter, 
# we are setting the max characters allowed before truncation to unlimited
pd.set_option("display.max_colwidth", None)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Jenkir\\Desktop\\cherry-tree-lane-analytics\\INDUSTRIES\\Materials-GICsector-EDA'

# %%
os.chdir('C:\\Users\\Jenkir\\Desktop\\cherry-tree-lane-analytics\\INDUSTRIES\\Materials-GICsector-EDA')
os.getcwd()
# Out:
# 'C:\\Users\\Jenkir\\Desktop\\cherry-tree-lane-analytics\\INDUSTRIES\\Materials-GICsector-EDA'

# %%
# see https://www.youtube.com/watch?v=r7t71t5993s  for how to add quotes and commas to values in Excel
# ids source file: 
headers = {
    "Api-key": api_key
          }

ids = ["243688",
"194060",
"202406",
"206642",
"206404",
"189956",
"190398",
"245305",
"194047",
"206013"
      ]
api_data = []

for i in ids:
    details = requests.get("https://api.esganalytics.io/api/company/details/?company_id={}".format(i), headers=headers)
    
    if details.status_code == 200:
        api_data.append(details.json())
    else:
        print("Request to { failed}".format(i))
   
pprint(api_data)
# Out:
# [{'all_executives': [{'bonus': 0,
#                       'dob': '1965-01-01',
#                       'name': 'Mr. John A. Hayes',
#                       'non_equity_incentives': 3902076,
#                       'option_awards': 2800000,
#                       'other_comp': 67359,
#                       'pension_and_deferred': 73183,
#                       'salary': 1299013,
#                       'stock_awards': 2800014,
#                       'title': 'Chairman, Pres & CEO',
#                       'total_compensation': 10941645},
#                      {'bonus': 0,
#                       'dob': '1966-01-01',
#                       'name': 'Mr. Mark J. Costa',
#                       'non_equity_incentives': 1540625,
#                       'option_awards': 2946429,
#                       'other_comp': 373043,
#                       'pension_and_deferred': 186226,
#                       'salary': 1226110,
#                       'stock_awards': 9646050,
#                       'title': 'Chairman & CEO',
#                       'total_compensation': 15918483},
#                      {'bonus': 0,
#                       'dob': '1962-01-01',
#                       'name': 'Mr. Edward L. Doheny II',
#                       'non_equity_incentives': 0,
#                       'option_awards': 0,
#                       'other_comp': 59118,
#                       'pension_and_deferred': 0,
#                       'salary': 1150000,
#                       'stock_awards': 7725109,
#                       'title': 'CEO, Pres & Director',
#                       'total_compensation': 8934227},
#                      {'bonus': 0,
#                       'dob': '1962-01-01',
#                       'name': 'Mr. Andreas  Fibig',
#                       'non_equity_incentives': 2634583,
#                       'option_awards': 0,
#                       'other_comp': 491396,
#                       'pension_and_deferred': 0,
#                       'salary': 1300000,
#                       'stock_awards': 4095961,
#                       'title': 'Chairman & CEO',
#                       'total_compensation': 8521940},
#                      {'bonus': 0,
#                       'dob': '1959-01-01',
#                       'name': 'Mr. Douglas M. Baker Jr.',
#                       'non_equity_incentives': 2284000,
#                       'option_awards': 5328337,
#                       'other_comp': 254004,
#                       'pension_and_deferred': 0,
#                       'salary': 1278125,
#                       'stock_awards': 5219567,
#                       'title': 'Chairman & CEO',
#                       'total_compensation': 14364033},
#                      {'bonus': 0,
#                       'dob': '1961-01-01',
#                       'name': "Mr. James C. O'Rourke P.Eng.",
#                       'non_equity_incentives': 2978300,
#                       'option_awards': 0,
#                       'other_comp': 769009,
#                       'pension_and_deferred': 0,
#                       'salary': 1178750,
#                       'stock_awards': 5599995,
#                       'title': 'CEO, Pres & Director',
#                       'total_compensation': 10526054}],
#   'company_detail': [{'address': 'Unit 1, Winnemucca, NV, United States, 89445',
#                       'company_name': 'Hycroft Mining Holding Corporation',
#                       'company_pulse': -0.08954375,
#                       'description': 'Hycroft Mining Holding Corporation, '
#                                      'together with its subsidiaries, operates '
#                                      'as a gold and silver development company '
#                                      'in the United States. The company holds '
#                                      'interests in the Hycroft mine that '
#                                      'covers an area of approximately 70,671 '
#                                      'acres located in the state of Nevada. As '
#                                      'of December 31, 2021, its Hycroft mine '
#                                      'had measured and indicated mineral '
#                                      'resources of 9.6 million ounces of gold, '
#                                      'and 446.0 million ounces of silver. '
#                                      'Hycroft Mining Holding Corporation is '
#                                      'headquartered in Winnemucca, Nevada.',
#                       'esg_beta': None,
#                       'esg_beta_tseries': None,
#                       'gicSector': 'Materials',
#                       'gicSubIndustry': 'Gold',
#                       'id': 243688,
#                       'pos_neg_ratio': [{'sentiment_rank': 'negative',
#                                          'total': 7},
#                                         {'sentiment_rank': 'positive',
#                                          'total': 9}],
#                       'url': 'https://www.hycroftmining.com'}],
#   'executives': [{'bonus': 0,
#                   'dob': '1960-01-01',
#                   'name': 'Dr. Diane Renee Garrett Eng., M.A., M.S., Mineral '
#                           'Eco, Ph.D.',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Pres, CEO & Director',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1959-01-01',
#                   'name': 'Mr. Stanton K. Rideout CPA, CPA, MBA',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Exec. VP & CFO',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': None,
#                   'name': 'Nigel  Bain',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'VP of Operations',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': None,
#                   'name': 'Mr. Alex  Davidson',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'VP of Exploration',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': None,
#                   'name': 'David S. Stone',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Corp. Sec.',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': None,
#                   'name': 'Ms. Ashlie  Thorburn',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'VP & Controller',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': None,
#                   'name': 'Mr. Mike  Eiselein',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'VP & GM',
#                   'total_compensation': 0}],
#   'indicators': [],
#   'securities': [{'code': 'HYMC',
#                   'currency_code': 'USD',
#                   'cusip': 'NA',
#                   'exchange': ' NASDAQ Exchnage',
#                   'exchange_id': 75,
#                   'isin': 'US44862P1093',
#                   'securities_type': 'Common Stock'}]},
#  {'all_executives': [{'bonus': 0,
#                       'dob': '1965-01-01',
#                       'name': 'Mr. John A. Hayes',
#                       'non_equity_incentives': 3902076,
#                       'option_awards': 2800000,
#                       'other_comp': 67359,
#                       'pension_and_deferred': 73183,
#                       'salary': 1299013,
#                       'stock_awards': 2800014,
#                       'title': 'Chairman, Pres & CEO',
#                       'total_compensation': 10941645},
#                      {'bonus': 0,
#                       'dob': '1966-01-01',
#                       'name': 'Mr. Mark J. Costa',
#                       'non_equity_incentives': 1540625,
#                       'option_awards': 2946429,
#                       'other_comp': 373043,
#                       'pension_and_deferred': 186226,
#                       'salary': 1226110,
#                       'stock_awards': 9646050,
#                       'title': 'Chairman & CEO',
#                       'total_compensation': 15918483},
#                      {'bonus': 0,
#                       'dob': '1962-01-01',
#                       'name': 'Mr. Edward L. Doheny II',
#                       'non_equity_incentives': 0,
#                       'option_awards': 0,
#                       'other_comp': 59118,
#                       'pension_and_deferred': 0,
#                       'salary': 1150000,
#                       'stock_awards': 7725109,
#                       'title': 'CEO, Pres & Director',
#                       'total_compensation': 8934227},
#                      {'bonus': 0,
#                       'dob': '1962-01-01',
#                       'name': 'Mr. Andreas  Fibig',
#                       'non_equity_incentives': 2634583,
#                       'option_awards': 0,
#                       'other_comp': 491396,
#                       'pension_and_deferred': 0,
#                       'salary': 1300000,
#                       'stock_awards': 4095961,
#                       'title': 'Chairman & CEO',
#                       'total_compensation': 8521940},
#                      {'bonus': 0,
#                       'dob': '1959-01-01',
#                       'name': 'Mr. Douglas M. Baker Jr.',
#                       'non_equity_incentives': 2284000,
#                       'option_awards': 5328337,
#                       'other_comp': 254004,
#                       'pension_and_deferred': 0,
#                       'salary': 1278125,
#                       'stock_awards': 5219567,
#                       'title': 'Chairman & CEO',
#                       'total_compensation': 14364033},
#                      {'bonus': 0,
#                       'dob': '1961-01-01',
#                       'name': "Mr. James C. O'Rourke P.Eng.",
#                       'non_equity_incentives': 2978300,
#                       'option_awards': 0,
#                       'other_comp': 769009,
#                       'pension_and_deferred': 0,
#                       'salary': 1178750,
#                       'stock_awards': 5599995,
#                       'title': 'CEO, Pres & Director',
#                       'total_compensation': 10526054}],
#   'company_detail': [{'address': 'Millenium Tower, Tel Aviv, Israel, 61070',
#                       'company_name': 'ICL Group Ltd',
#                       'company_pulse': 0.47390107422969163,
#                       'description': 'ICL Group Ltd, together with its '
#                                      'subsidiaries, operates as a specialty '
#                                      'minerals and chemicals company '
#                                      'worldwide. It operates in four segments: '
#                                      'Industrial Products, Potash, Phosphate '
#                                      'Solutions, and Innovative Ag Solutions '
#                                      '(IAS). The Industrial Products segment '
#                                      'produces bromine out of a solution that '
#                                      'is a by-product of the potash production '
#                                      'process, as well as bromine-based '
#                                      'compounds; produces various grades of '
#                                      'potash, salt, magnesium chloride, and '
#                                      'magnesia products; and produces and '
#                                      'markets phosphorous-based flame '
#                                      'retardants and other phosphorus-based '
#                                      'products. The Potash segment extracts '
#                                      'potash from the Dead Sea; mines and '
#                                      'produces potash and salt; produces '
#                                      'Polysulphate; produces, markets, and '
#                                      'sells magnesium and magnesium alloys, as '
#                                      'well as related by-products, including '
#                                      'chlorine and sylvinite; and sells salt. '
#                                      'The Phosphate Solutions segment produces '
#                                      'specialty products; produces and markets '
#                                      'phosphate-based fertilizers, as well as '
#                                      'sulphuric acid, green phosphoric acid, '
#                                      'and phosphate fertilizers; and '
#                                      'manufactures thermal phosphoric acid for '
#                                      'various industrial end markets, such as '
#                                      'oral care, cleaning products, paints and '
#                                      'coatings, water treatment, asphalt '
#                                      'modification, construction, and metal '
#                                      'treatment. It also develops and produces '
#                                      'functional food ingredients and '
#                                      'phosphate additives for use in the '
#                                      'processed meat, poultry, seafood, dairy, '
#                                      'beverage, and baked goods markets; and '
#                                      'produces milk and whey proteins for the '
#                                      'food ingredients industry. The IAS '
#                                      'segment develops, manufactures, markets, '
#                                      'and sells fertilizers based primarily on '
#                                      'nitrogen, potash, and phosphate, '
#                                      'including water soluble specialty, '
#                                      'liquid, soluble, and controlled-release '
#                                      'fertilizers. The company sells its '
#                                      'products through marketing companies, '
#                                      'agents, and distributors. The company '
#                                      'was formerly known as Israel Chemicals '
#                                      'Ltd. and changed its name to ICL Group '
#                                      'Ltd in May 2020. ICL Group Ltd was '
#                                      'founded in 1968 and is headquartered in '
#                                      'Tel Aviv, Israel.',
#                       'esg_beta': None,
#                       'esg_beta_tseries': None,
#                       'gicSector': 'Materials',
#                       'gicSubIndustry': 'Fertilizers & Agricultural Chemicals',
#                       'id': 194060,
#                       'pos_neg_ratio': [{'sentiment_rank': 'negative',
#                                          'total': 7},
#                                         {'sentiment_rank': 'positive',
#                                          'total': 78}],
#                       'url': 'http://www.icl-group.com'}],
#   'executives': [{'bonus': 0,
#                   'dob': '1964-01-01',
#                   'name': 'Mr. Raviv  Zoller',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Pres & CEO',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1968-01-01',
#                   'name': 'Mr. Kobi  Altman',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Chief Financial Officer',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1969-01-01',
#                   'name': 'Mr. Yoav  Doppelt',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Exec. Chairman',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1968-01-01',
#                   'name': 'Mr. Nitzan  Moshe',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Exec. VP of Global Operations',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1968-01-01',
#                   'name': 'Mr. Anantha N. Desikan',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Exec. VP and Chief Innovation & Technology Officer',
#                   'total_compensation': 0}],
#   'indicators': [{'Adult Activity': 'No',
#                   'Alcohol': 'No',
#                   'Animal Testing': 'No',
#                   'Catholic Values': 'No',
#                   'Clean Oceans': '',
#                   'Coal': 'No',
#                   'Controversial Weapons': 'No',
#                   'Deforestation': '',
#                   'Deforestation Financing': '',
#                   'Fur & Leather': 'No',
#                   'GMO': 'No',
#                   'Gambling': 'No',
#                   'Gender Equality': 'Yes',
#                   'Innovation': '',
#                   'Military Contracts': 'No',
#                   'Nuclear': 'No',
#                   'Oil & Gas': '',
#                   'Palm Oil': 'No',
#                   'Pesticides': 'No',
#                   'Prison Industry': '',
#                   'Renewable Energy': '',
#                   'Small Arms': 'No',
#                   'Tobacco': 'No'}],
#   'securities': [{'code': 'ICL',
#                   'currency_code': 'USD',
#                   'cusip': '465036200',
#                   'exchange': 'New York Stock Exchange',
#                   'exchange_id': 69,
#                   'isin': 'US4650471083',
#                   'securities_type': 'Common Stock'},
#                  {'code': 'ICL',
#                   'currency_code': 'ILS',
#                   'cusip': '',
#                   'exchange': 'Tel Aviv Exchange',
#                   'exchange_id': 32,
#                   'isin': 'IL0002810146',
#                   'securities_type': 'Common Stock'}]},
#  {'all_executives': [{'bonus': 0,
#                       'dob': '1965-01-01',
#                       'name': 'Mr. John A. Hayes',
#                       'non_equity_incentives': 3902076,
#                       'option_awards': 2800000,
#                       'other_comp': 67359,
#                       'pension_and_deferred': 73183,
#                       'salary': 1299013,
#                       'stock_awards': 2800014,
#                       'title': 'Chairman, Pres & CEO',
#                       'total_compensation': 10941645},
#                      {'bonus': 0,
#                       'dob': '1966-01-01',
#                       'name': 'Mr. Mark J. Costa',
#                       'non_equity_incentives': 1540625,
#                       'option_awards': 2946429,
#                       'other_comp': 373043,
#                       'pension_and_deferred': 186226,
#                       'salary': 1226110,
#                       'stock_awards': 9646050,
#                       'title': 'Chairman & CEO',
#                       'total_compensation': 15918483},
#                      {'bonus': 0,
#                       'dob': '1962-01-01',
#                       'name': 'Mr. Edward L. Doheny II',
#                       'non_equity_incentives': 0,
#                       'option_awards': 0,
#                       'other_comp': 59118,
#                       'pension_and_deferred': 0,
#                       'salary': 1150000,
#                       'stock_awards': 7725109,
#                       'title': 'CEO, Pres & Director',
#                       'total_compensation': 8934227},
#                      {'bonus': 0,
#                       'dob': '1962-01-01',
#                       'name': 'Mr. Andreas  Fibig',
#                       'non_equity_incentives': 2634583,
#                       'option_awards': 0,
#                       'other_comp': 491396,
#                       'pension_and_deferred': 0,
#                       'salary': 1300000,
#                       'stock_awards': 4095961,
#                       'title': 'Chairman & CEO',
#                       'total_compensation': 8521940},
#                      {'bonus': 0,
#                       'dob': '1959-01-01',
#                       'name': 'Mr. Douglas M. Baker Jr.',
#                       'non_equity_incentives': 2284000,
#                       'option_awards': 5328337,
#                       'other_comp': 254004,
#                       'pension_and_deferred': 0,
#                       'salary': 1278125,
#                       'stock_awards': 5219567,
#                       'title': 'Chairman & CEO',
#                       'total_compensation': 14364033},
#                      {'bonus': 0,
#                       'dob': '1961-01-01',
#                       'name': "Mr. James C. O'Rourke P.Eng.",
#                       'non_equity_incentives': 2978300,
#                       'option_awards': 0,
#                       'other_comp': 769009,
#                       'pension_and_deferred': 0,
#                       'salary': 1178750,
#                       'stock_awards': 5599995,
#                       'title': 'CEO, Pres & Director',
#                       'total_compensation': 10526054}],
#   'company_detail': [{'address': '75/102, Ocean Tower 2, Bangkok, Thailand, '
#                                  '10110',
#                       'company_name': 'Indorama Ventures Public Company '
#                                       'Limited',
#                       'company_pulse': 0.36554597701149427,
#                       'description': 'Indorama Ventures Public Company Limited '
#                                      'produces and distributes polyethylene '
#                                      'terephthalate (PET), purified '
#                                      'terephthalic acid (PTA), paraxylene, '
#                                      'isophthalic acid, ethylene oxide and '
#                                      'ethylene glycol, naphthalene '
#                                      'dicarboxylate, polyester fibers and '
#                                      'yarns, and wool products. It operates in '
#                                      'five segments: Integrated PET, Fibers, '
#                                      'Packaging, Integrated Oxides and '
#                                      'Derivatives, and Specialty Chemicals. '
#                                      'The company produces hot-fill, high and '
#                                      'low intrinsic viscosity, quick heat and '
#                                      'general grade PET products for use in as '
#                                      'a raw material in the manufacture of '
#                                      'bottles, sheets, films, fibers, '
#                                      'filaments, and other specialty products; '
#                                      'and packaging materials, such as molding '
#                                      'bottles, bottle caps, and bottles. It '
#                                      'also provides monoethylene glycol, '
#                                      'diethylene glycol, triethylene glycol, '
#                                      'and purified ethylene oxide; and '
#                                      'polyester, rayon, nylon, polypropylene, '
#                                      'composites, and worsted wool fibers. In '
#                                      'addition, the company offers fibers, '
#                                      'including polyester fibers and yarns, '
#                                      'polyolefin fibers, bicomponent fibers, '
#                                      'and other fibers for home, apparel, '
#                                      'hygiene and medical, automotive, and '
#                                      'industrial/technical markets; Further, '
#                                      'it provides recycled products, such as '
#                                      'bottle flakes, recycled PET, and '
#                                      'recycled fibers; and wool products, '
#                                      'including weaving, stretch, knitting, '
#                                      'environmentally-friendly, compact, and '
#                                      'special end use yarns. The company '
#                                      'operates in Thailand, North America, '
#                                      'Europe, and internationally. The company '
#                                      'is headquartered in Bangkok, Thailand. '
#                                      'Indorama Ventures Public Company Limited '
#                                      'is a subsidiary of Indorama Resources '
#                                      'Limited.',
#                       'esg_beta': None,
#                       'esg_beta_tseries': None,
#                       'gicSector': 'Materials',
#                       'gicSubIndustry': 'Commodity Chemicals',
#                       'id': 202406,
#                       'pos_neg_ratio': [{'sentiment_rank': 'negative',
#                                          'total': 5},
#                                         {'sentiment_rank': 'positive',
#                                          'total': 24}],
#                       'url': 'http://www.indoramaventures.com'}],
#   'executives': [{'bonus': 0,
#                   'dob': '1959-01-01',
#                   'name': 'Mr. Aloke  Lohia',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Vice Chairman & Group CEO',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1969-01-01',
#                   'name': 'Mr. Sanjay  Ahuja',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'CFO & Exec. Director',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1965-01-01',
#                   'name': 'Ms. Suchitra  Lohia',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Exec. Director',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1958-01-01',
#                   'name': 'Mr. Dilip Kumar Agarwal',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Exec. Director and CEO of Feedstock & PET Bus.',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1953-01-01',
#                   'name': 'Mr. Udey Paul Singh Gill',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Exec. Director & CEO of Fibers Bus.',
#                   'total_compensation': 0}],
#   'indicators': [],
#   'securities': [{'code': 'INDOY',
#                   'currency_code': 'USD',
#                   'cusip': '',
#                   'exchange': ' Pink',
#                   'exchange_id': 72,
#                   'isin': '',
#                   'securities_type': 'Common Stock'},
#                  {'code': 'I93',
#                   'currency_code': 'EUR',
#                   'cusip': '',
#                   'exchange': 'Frankfurt Exchange',
#                   'exchange_id': 12,
#                   'isin': '',
#                   'securities_type': 'Common Stock'},
#                  {'code': 'IVL',
#                   'currency_code': 'THB',
#                   'cusip': '',
#                   'exchange': 'Thailand Exchange',
#                   'exchange_id': 44,
#                   'isin': 'TH1027010004',
#                   'securities_type': 'Common Stock'}]},
#  {'all_executives': [{'bonus': 0,
#                       'dob': '1965-01-01',
#                       'name': 'Mr. John A. Hayes',
#                       'non_equity_incentives': 3902076,
#                       'option_awards': 2800000,
#                       'other_comp': 67359,
#                       'pension_and_deferred': 73183,
#                       'salary': 1299013,
#                       'stock_awards': 2800014,
#                       'title': 'Chairman, Pres & CEO',
#                       'total_compensation': 10941645},
#                      {'bonus': 0,
#                       'dob': '1966-01-01',
#                       'name': 'Mr. Mark J. Costa',
#                       'non_equity_incentives': 1540625,
#                       'option_awards': 2946429,
#                       'other_comp': 373043,
#                       'pension_and_deferred': 186226,
#                       'salary': 1226110,
#                       'stock_awards': 9646050,
#                       'title': 'Chairman & CEO',
#                       'total_compensation': 15918483},
#                      {'bonus': 0,
#                       'dob': '1962-01-01',
#                       'name': 'Mr. Edward L. Doheny II',
#                       'non_equity_incentives': 0,
#                       'option_awards': 0,
#                       'other_comp': 59118,
#                       'pension_and_deferred': 0,
#                       'salary': 1150000,
#                       'stock_awards': 7725109,
#                       'title': 'CEO, Pres & Director',
#                       'total_compensation': 8934227},
#                      {'bonus': 0,
#                       'dob': '1962-01-01',
#                       'name': 'Mr. Andreas  Fibig',
#                       'non_equity_incentives': 2634583,
#                       'option_awards': 0,
#                       'other_comp': 491396,
#                       'pension_and_deferred': 0,
#                       'salary': 1300000,
#                       'stock_awards': 4095961,
#                       'title': 'Chairman & CEO',
#                       'total_compensation': 8521940},
#                      {'bonus': 0,
#                       'dob': '1959-01-01',
#                       'name': 'Mr. Douglas M. Baker Jr.',
#                       'non_equity_incentives': 2284000,
#                       'option_awards': 5328337,
#                       'other_comp': 254004,
#                       'pension_and_deferred': 0,
#                       'salary': 1278125,
#                       'stock_awards': 5219567,
#                       'title': 'Chairman & CEO',
#                       'total_compensation': 14364033},
#                      {'bonus': 0,
#                       'dob': '1961-01-01',
#                       'name': "Mr. James C. O'Rourke P.Eng.",
#                       'non_equity_incentives': 2978300,
#                       'option_awards': 0,
#                       'other_comp': 769009,
#                       'pension_and_deferred': 0,
#                       'salary': 1178750,
#                       'stock_awards': 5599995,
#                       'title': 'CEO, Pres & Director',
#                       'total_compensation': 10526054}],
#   'company_detail': [{'address': '5255 Virginia Avenue, North Charleston, SC, '
#                                  'United States, 29406',
#                       'company_name': 'Ingevity Corporation',
#                       'company_pulse': 0.4607875724637682,
#                       'description': 'Ingevity Corporation manufactures and '
#                                      'sells specialty chemicals and activated '
#                                      'carbon materials in North America, '
#                                      'Europe, the Asia-Pacific, and '
#                                      'internationally. The company operates '
#                                      'through two segments, Performance '
#                                      'Materials and Performance Chemicals. The '
#                                      'Performance Materials segment engineers, '
#                                      'manufactures, and sells hardwood-based '
#                                      'and chemically activated carbon products '
#                                      'primarily for use in gasoline vapor '
#                                      'emission control systems in cars, '
#                                      'trucks, motorcycles, and boats. This '
#                                      'segment also produces other activated '
#                                      'carbon products for use in various '
#                                      'applications, including food, water, '
#                                      'beverage, and chemical purification. The '
#                                      'Performance Chemicals segment develops, '
#                                      'manufactures, and sells a range of '
#                                      'specialty chemicals derived from '
#                                      'co-products of the kraft pulping process '
#                                      'and caprolactone monomers. This '
#                                      "segment's products are used in various "
#                                      'applications comprising pavement '
#                                      'preservation, pavement adhesion '
#                                      'promotion, and warm mix paving; oil well '
#                                      'service additives, oil production, and '
#                                      'downstream application chemicals; '
#                                      'printing inks, adhesives, agrochemicals, '
#                                      'lubricants, and industrial '
#                                      'intermediates; and coatings, resins, '
#                                      'elastomers, and bio-plastics. Ingevity '
#                                      'Corporation was incorporated in 2015 and '
#                                      'is headquartered in North Charleston, '
#                                      'South Carolina.',
#                       'esg_beta': None,
#                       'esg_beta_tseries': None,
#                       'gicSector': 'Materials',
#                       'gicSubIndustry': 'Specialty Chemicals',
#                       'id': 206642,
#                       'pos_neg_ratio': [{'sentiment_rank': 'negative',
#                                          'total': 6},
#                                         {'sentiment_rank': 'positive',
#                                          'total': 40}],
#                       'url': 'http://www.ingevity.com'}],
#   'executives': [{'bonus': 0,
#                   'dob': '1947-01-01',
#                   'name': 'Mr. Richard B. Kelson',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Chairman and Interim Pres & CEO',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1967-01-01',
#                   'name': 'Mr. John C. Fortson',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Exec. VP, CFO & Treasurer',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1958-01-01',
#                   'name': 'Ms. Katherine Pryor Burgeson',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Exec. VP, Gen. Counsel & Sec.',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1966-01-01',
#                   'name': 'Mr. Stuart Edward Woodcock Jr.',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Exec. VP & Pres of Performance Materials',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1961-01-01',
#                   'name': 'Mr. Michael P. Smith',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Exec. VP and Pres of Performance Chemicals, '
#                            'Strategy & Bus. Devel.',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1967-01-01',
#                   'name': 'Mr. John C. Fortson',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Pres, CEO & Director',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1958-01-01',
#                   'name': 'Ms. Mary Dean Hall',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Exec. VP & CFO',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1971-01-01',
#                   'name': 'Ms. Stacy Lancaster Cozad',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Exec. VP, Gen. Counsel & Sec.',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1981-01-01',
#                   'name': 'Mr. Phillip John Platt',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Chief Accounting Officer, Corp. Controller & VP of '
#                            'Financial Planning',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': None,
#                   'name': 'Mr. Daniel  Gallagher',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'VP of Investor Relations',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': None,
#                   'name': 'John  Nypaver',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'VP of Treasurer & Investor Relations',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': None,
#                   'name': 'Ms. Christine  Stunyo',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Sr. VP & Chief HR Officer',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1963-01-01',
#                   'name': 'Mr. Richard  White',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Sr. VP of Performance Chemicals and Pres of '
#                            'Industrial Specialties & Pavement Technologies',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': None,
#                   'name': 'Mr. Erik  Ripple',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Sr. VP and Chief Growth & Innovation Officer',
#                   'total_compensation': 0}],
#   'indicators': [{'Adult Activity': None,
#                   'Alcohol': None,
#                   'Animal Testing': None,
#                   'Catholic Values': None,
#                   'Clean Oceans': '',
#                   'Coal': None,
#                   'Controversial Weapons': None,
#                   'Deforestation': '',
#                   'Deforestation Financing': '',
#                   'Fur & Leather': None,
#                   'GMO': None,
#                   'Gambling': None,
#                   'Gender Equality': '',
#                   'Innovation': '',
#                   'Military Contracts': None,
#                   'Nuclear': None,
#                   'Oil & Gas': '',
#                   'Palm Oil': None,
#                   'Pesticides': None,
#                   'Prison Industry': '',
#                   'Renewable Energy': '',
#                   'Small Arms': None,
#                   'Tobacco': None}],
#   'securities': [{'code': 'NGVT',
#                   'currency_code': 'USD',
#                   'cusip': '45688C107',
#                   'exchange': 'New York Stock Exchange',
#                   'exchange_id': 69,
#                   'isin': 'US45688C1071',
#                   'securities_type': 'Common Stock'},
#                  {'code': 'IGX',
#                   'currency_code': 'EUR',
#                   'cusip': 'NA',
#                   'exchange': 'Frankfurt Exchange',
#                   'exchange_id': 12,
#                   'isin': 'US45688C1071',
#                   'securities_type': 'Common Stock'}]},
#  {'all_executives': [{'bonus': 0,
#                       'dob': '1965-01-01',
#                       'name': 'Mr. John A. Hayes',
#                       'non_equity_incentives': 3902076,
#                       'option_awards': 2800000,
#                       'other_comp': 67359,
#                       'pension_and_deferred': 73183,
#                       'salary': 1299013,
#                       'stock_awards': 2800014,
#                       'title': 'Chairman, Pres & CEO',
#                       'total_compensation': 10941645},
#                      {'bonus': 0,
#                       'dob': '1966-01-01',
#                       'name': 'Mr. Mark J. Costa',
#                       'non_equity_incentives': 1540625,
#                       'option_awards': 2946429,
#                       'other_comp': 373043,
#                       'pension_and_deferred': 186226,
#                       'salary': 1226110,
#                       'stock_awards': 9646050,
#                       'title': 'Chairman & CEO',
#                       'total_compensation': 15918483},
#                      {'bonus': 0,
#                       'dob': '1962-01-01',
#                       'name': 'Mr. Edward L. Doheny II',
#                       'non_equity_incentives': 0,
#                       'option_awards': 0,
#                       'other_comp': 59118,
#                       'pension_and_deferred': 0,
#                       'salary': 1150000,
#                       'stock_awards': 7725109,
#                       'title': 'CEO, Pres & Director',
#                       'total_compensation': 8934227},
#                      {'bonus': 0,
#                       'dob': '1962-01-01',
#                       'name': 'Mr. Andreas  Fibig',
#                       'non_equity_incentives': 2634583,
#                       'option_awards': 0,
#                       'other_comp': 491396,
#                       'pension_and_deferred': 0,
#                       'salary': 1300000,
#                       'stock_awards': 4095961,
#                       'title': 'Chairman & CEO',
#                       'total_compensation': 8521940},
#                      {'bonus': 0,
#                       'dob': '1959-01-01',
#                       'name': 'Mr. Douglas M. Baker Jr.',
#                       'non_equity_incentives': 2284000,
#                       'option_awards': 5328337,
#                       'other_comp': 254004,
#                       'pension_and_deferred': 0,
#                       'salary': 1278125,
#                       'stock_awards': 5219567,
#                       'title': 'Chairman & CEO',
#                       'total_compensation': 14364033},
#                      {'bonus': 0,
#                       'dob': '1961-01-01',
#                       'name': "Mr. James C. O'Rourke P.Eng.",
#                       'non_equity_incentives': 2978300,
#                       'option_awards': 0,
#                       'other_comp': 769009,
#                       'pension_and_deferred': 0,
#                       'salary': 1178750,
# ...
#                                      'South America, and internationally. It '
#                                      'extracts raw materials, including potash '
#                                      'and bromine from Dead Sea; and specialty '
#                                      'phosphates from phosphate rock mines. '
#                                      'The company offers bromine-based flame '
#                                      'retardants and industrial solutions; '
#                                      'elemental bromine; bromine compounds; '
#                                      'magnesium; phosphorous-based industrial '
#                                      'compounds; specialty agriculture '
#                                      'products; phosphate fertilizers; green '
#                                      'phosphoric acid; phosphorus-based flame '
#                                      'retardants; clear brine fluids; calcium '
#                                      'products; brominated biocides; organic '
#                                      'and inorganic bromides; potassium '
#                                      'chloride; magnesium dichloride; and '
#                                      'magnesia products. It also provide '
#                                      'specialty fertilizers, including soluble '
#                                      'fertilizers, which includes '
#                                      'water-soluble straights and '
#                                      'water-soluble NPK; controlled release '
#                                      'fertilizers; and liquid NPK fertilizers. '
#                                      'In addition, the company produces fuel '
#                                      'products; raw materials for the '
#                                      'petrochemical industry; materials for '
#                                      'the plastics industry; and oils, waxes, '
#                                      'and related products, as well as '
#                                      'provides power and water, including '
#                                      'steam services to various industries in '
#                                      'Haifa. Its products are primarily used '
#                                      'in the areas of agriculture, '
#                                      'electronics, construction, automotive, '
#                                      'oil drilling, food, furniture, '
#                                      'pharmaceutical, textile, water '
#                                      'treatment, metal treatment, oral care, '
#                                      'carbonated drinks, asphalt modification, '
#                                      'paints and coatings, and other '
#                                      'industries. The company was founded in '
#                                      '1968 and is based in Tel Aviv, Israel.',
#                       'esg_beta': None,
#                       'esg_beta_tseries': None,
#                       'gicSector': 'Materials',
#                       'gicSubIndustry': 'Fertilizers & Agricultural Chemicals',
#                       'id': 194047,
#                       'pos_neg_ratio': [{'sentiment_rank': 'positive',
#                                          'total': 2}],
#                       'url': 'http://www.israelcorp.com'}],
#   'executives': [{'bonus': 0,
#                   'dob': '1976-01-01',
#                   'name': 'Mr. Sagi  Kabala',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Chief Financial Officer',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1972-01-01',
#                   'name': 'Ms. Maya  Alschich-Kaplan',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Exec. VP, Gen. Counsel & Company Sec.',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1945-01-01',
#                   'name': 'Mr. Ovadia  Eli',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Chairman of ORL',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1959-01-01',
#                   'name': 'Mr. Charles Michael Weidhas',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'CEO & Pres of ICL Industrial Products',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1950-01-01',
#                   'name': 'Mr. Asher  Grinbaum',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'COO of Israel Chemicals Ltd. and Exec. VP of '
#                            'Israel Chemicals Ltd.',
#                   'total_compensation': 0}],
#   'indicators': [],
#   'securities': [{'code': 'IRLCF',
#                   'currency_code': 'USD',
#                   'cusip': '',
#                   'exchange': ' Pink',
#                   'exchange_id': 72,
#                   'isin': '',
#                   'securities_type': 'Common Stock'},
#                  {'code': 'ILCO',
#                   'currency_code': 'ILS',
#                   'cusip': '',
#                   'exchange': 'Tel Aviv Exchange',
#                   'exchange_id': 32,
#                   'isin': 'IL0005760173',
#                   'securities_type': 'Common Stock'}]},
#  {'all_executives': [{'bonus': 0,
#                       'dob': '1965-01-01',
#                       'name': 'Mr. John A. Hayes',
#                       'non_equity_incentives': 3902076,
#                       'option_awards': 2800000,
#                       'other_comp': 67359,
#                       'pension_and_deferred': 73183,
#                       'salary': 1299013,
#                       'stock_awards': 2800014,
#                       'title': 'Chairman, Pres & CEO',
#                       'total_compensation': 10941645},
#                      {'bonus': 0,
#                       'dob': '1966-01-01',
#                       'name': 'Mr. Mark J. Costa',
#                       'non_equity_incentives': 1540625,
#                       'option_awards': 2946429,
#                       'other_comp': 373043,
#                       'pension_and_deferred': 186226,
#                       'salary': 1226110,
#                       'stock_awards': 9646050,
#                       'title': 'Chairman & CEO',
#                       'total_compensation': 15918483},
#                      {'bonus': 0,
#                       'dob': '1962-01-01',
#                       'name': 'Mr. Edward L. Doheny II',
#                       'non_equity_incentives': 0,
#                       'option_awards': 0,
#                       'other_comp': 59118,
#                       'pension_and_deferred': 0,
#                       'salary': 1150000,
#                       'stock_awards': 7725109,
#                       'title': 'CEO, Pres & Director',
#                       'total_compensation': 8934227},
#                      {'bonus': 0,
#                       'dob': '1962-01-01',
#                       'name': 'Mr. Andreas  Fibig',
#                       'non_equity_incentives': 2634583,
#                       'option_awards': 0,
#                       'other_comp': 491396,
#                       'pension_and_deferred': 0,
#                       'salary': 1300000,
#                       'stock_awards': 4095961,
#                       'title': 'Chairman & CEO',
#                       'total_compensation': 8521940},
#                      {'bonus': 0,
#                       'dob': '1959-01-01',
#                       'name': 'Mr. Douglas M. Baker Jr.',
#                       'non_equity_incentives': 2284000,
#                       'option_awards': 5328337,
#                       'other_comp': 254004,
#                       'pension_and_deferred': 0,
#                       'salary': 1278125,
#                       'stock_awards': 5219567,
#                       'title': 'Chairman & CEO',
#                       'total_compensation': 14364033},
#                      {'bonus': 0,
#                       'dob': '1961-01-01',
#                       'name': "Mr. James C. O'Rourke P.Eng.",
#                       'non_equity_incentives': 2978300,
#                       'option_awards': 0,
#                       'other_comp': 769009,
#                       'pension_and_deferred': 0,
#                       'salary': 1178750,
#                       'stock_awards': 5599995,
#                       'title': 'CEO, Pres & Director',
#                       'total_compensation': 10526054}],
#   'company_detail': [{'address': '999 Canada Place, Vancouver, BC, Canada, V6C '
#                                  '3E1',
#                       'company_name': 'Ivanhoe Mines Ltd',
#                       'company_pulse': 0.31721250000000006,
#                       'description': 'Ivanhoe Mines Ltd. engages in the '
#                                      'exploration, development, and recovery '
#                                      'of minerals and precious metals located '
#                                      'primarily in Africa. The company '
#                                      'explores for platinum, palladium, '
#                                      'nickel, copper, gold, rhodium, zinc, '
#                                      'germanium, and lead deposits. Its '
#                                      'projects include the Platreef project '
#                                      'located in the Northern Limb of South '
#                                      "Africa's Bushveld Complex; the Kipushi "
#                                      "project located on the DRC's Copperbelt; "
#                                      'and the Kamoa-Kakula project located '
#                                      'within the Central African Copperbelt. '
#                                      'It also holds a 100% interest in the '
#                                      'Western Foreland exploration project '
#                                      'covering an area of approximately 2,550 '
#                                      'square kilometers located in the '
#                                      'Democratic Republic of Congo. The '
#                                      'company was formerly known as Ivanplats '
#                                      'Limited and changed its name to Ivanhoe '
#                                      'Mines Ltd. in August 2013. Ivanhoe Mines '
#                                      'Ltd. was incorporated in 1993 and is '
#                                      'headquartered in Vancouver, Canada.',
#                       'esg_beta': None,
#                       'esg_beta_tseries': None,
#                       'gicSector': 'Materials',
#                       'gicSubIndustry': 'Diversified Metals & Mining',
#                       'id': 206013,
#                       'pos_neg_ratio': [{'sentiment_rank': 'negative',
#                                          'total': 3},
#                                         {'sentiment_rank': 'positive',
#                                          'total': 11}],
#                       'url': 'http://www.ivanhoemines.com'}],
#   'executives': [{'bonus': 0,
#                   'dob': '1951-01-01',
#                   'name': 'Mr. Robert Martin  Friedland',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Founder & Exec. Co-Chairman',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1961-01-01',
#                   'name': 'Mr. Egizio  Bianchini',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Exec. Vice Chairman',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1977-01-01',
#                   'name': 'Ms. Martie  Cloete',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Pres & CFO',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1959-01-01',
#                   'name': 'Mr. Warwick P. Morley-Jepson',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Exec. VP & COO',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': None,
#                   'name': 'Ms. Mary A. Vincelli',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'VP of Compliance & Corp. Sec.',
#                   'total_compensation': 0}],
#   'indicators': [{'Adult Activity': None,
#                   'Alcohol': None,
#                   'Animal Testing': None,
#                   'Catholic Values': None,
#                   'Clean Oceans': '',
#                   'Coal': None,
#                   'Controversial Weapons': None,
#                   'Deforestation': '',
#                   'Deforestation Financing': '',
#                   'Fur & Leather': None,
#                   'GMO': None,
#                   'Gambling': None,
#                   'Gender Equality': '',
#                   'Innovation': '',
#                   'Military Contracts': None,
#                   'Nuclear': None,
#                   'Oil & Gas': '',
#                   'Palm Oil': None,
#                   'Pesticides': None,
#                   'Prison Industry': '',
#                   'Renewable Energy': '',
#                   'Small Arms': None,
#                   'Tobacco': None}],
#   'securities': [{'code': 'IVPAF',
#                   'currency_code': 'USD',
#                   'cusip': '',
#                   'exchange': ' OTC QX Exchange',
#                   'exchange_id': 78,
#                   'isin': '',
#                   'securities_type': 'Common Stock'},
#                  {'code': 'IVN',
#                   'currency_code': 'CAD',
#                   'cusip': '',
#                   'exchange': 'Toronto Exchange',
#                   'exchange_id': 3,
#                   'isin': 'CA46579R1047',
#                   'securities_type': 'Common Stock'},
#                  {'code': 'IYAA',
#                   'currency_code': 'EUR',
#                   'cusip': '',
#                   'exchange': 'Frankfurt Exchange',
#                   'exchange_id': 12,
#                   'isin': '',
#                   'securities_type': 'Common Stock'}]}]

# %%
json_data = json.dumps(api_data)
dict_data = json.loads(json_data)
pprint(dict_data)
# Out:
# [{'all_executives': [{'bonus': 0,
#                       'dob': '1965-01-01',
#                       'name': 'Mr. John A. Hayes',
#                       'non_equity_incentives': 3902076,
#                       'option_awards': 2800000,
#                       'other_comp': 67359,
#                       'pension_and_deferred': 73183,
#                       'salary': 1299013,
#                       'stock_awards': 2800014,
#                       'title': 'Chairman, Pres & CEO',
#                       'total_compensation': 10941645},
#                      {'bonus': 0,
#                       'dob': '1966-01-01',
#                       'name': 'Mr. Mark J. Costa',
#                       'non_equity_incentives': 1540625,
#                       'option_awards': 2946429,
#                       'other_comp': 373043,
#                       'pension_and_deferred': 186226,
#                       'salary': 1226110,
#                       'stock_awards': 9646050,
#                       'title': 'Chairman & CEO',
#                       'total_compensation': 15918483},
#                      {'bonus': 0,
#                       'dob': '1962-01-01',
#                       'name': 'Mr. Edward L. Doheny II',
#                       'non_equity_incentives': 0,
#                       'option_awards': 0,
#                       'other_comp': 59118,
#                       'pension_and_deferred': 0,
#                       'salary': 1150000,
#                       'stock_awards': 7725109,
#                       'title': 'CEO, Pres & Director',
#                       'total_compensation': 8934227},
#                      {'bonus': 0,
#                       'dob': '1962-01-01',
#                       'name': 'Mr. Andreas  Fibig',
#                       'non_equity_incentives': 2634583,
#                       'option_awards': 0,
#                       'other_comp': 491396,
#                       'pension_and_deferred': 0,
#                       'salary': 1300000,
#                       'stock_awards': 4095961,
#                       'title': 'Chairman & CEO',
#                       'total_compensation': 8521940},
#                      {'bonus': 0,
#                       'dob': '1959-01-01',
#                       'name': 'Mr. Douglas M. Baker Jr.',
#                       'non_equity_incentives': 2284000,
#                       'option_awards': 5328337,
#                       'other_comp': 254004,
#                       'pension_and_deferred': 0,
#                       'salary': 1278125,
#                       'stock_awards': 5219567,
#                       'title': 'Chairman & CEO',
#                       'total_compensation': 14364033},
#                      {'bonus': 0,
#                       'dob': '1961-01-01',
#                       'name': "Mr. James C. O'Rourke P.Eng.",
#                       'non_equity_incentives': 2978300,
#                       'option_awards': 0,
#                       'other_comp': 769009,
#                       'pension_and_deferred': 0,
#                       'salary': 1178750,
#                       'stock_awards': 5599995,
#                       'title': 'CEO, Pres & Director',
#                       'total_compensation': 10526054}],
#   'company_detail': [{'address': 'Unit 1, Winnemucca, NV, United States, 89445',
#                       'company_name': 'Hycroft Mining Holding Corporation',
#                       'company_pulse': -0.08954375,
#                       'description': 'Hycroft Mining Holding Corporation, '
#                                      'together with its subsidiaries, operates '
#                                      'as a gold and silver development company '
#                                      'in the United States. The company holds '
#                                      'interests in the Hycroft mine that '
#                                      'covers an area of approximately 70,671 '
#                                      'acres located in the state of Nevada. As '
#                                      'of December 31, 2021, its Hycroft mine '
#                                      'had measured and indicated mineral '
#                                      'resources of 9.6 million ounces of gold, '
#                                      'and 446.0 million ounces of silver. '
#                                      'Hycroft Mining Holding Corporation is '
#                                      'headquartered in Winnemucca, Nevada.',
#                       'esg_beta': None,
#                       'esg_beta_tseries': None,
#                       'gicSector': 'Materials',
#                       'gicSubIndustry': 'Gold',
#                       'id': 243688,
#                       'pos_neg_ratio': [{'sentiment_rank': 'negative',
#                                          'total': 7},
#                                         {'sentiment_rank': 'positive',
#                                          'total': 9}],
#                       'url': 'https://www.hycroftmining.com'}],
#   'executives': [{'bonus': 0,
#                   'dob': '1960-01-01',
#                   'name': 'Dr. Diane Renee Garrett Eng., M.A., M.S., Mineral '
#                           'Eco, Ph.D.',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Pres, CEO & Director',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1959-01-01',
#                   'name': 'Mr. Stanton K. Rideout CPA, CPA, MBA',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Exec. VP & CFO',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': None,
#                   'name': 'Nigel  Bain',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'VP of Operations',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': None,
#                   'name': 'Mr. Alex  Davidson',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'VP of Exploration',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': None,
#                   'name': 'David S. Stone',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Corp. Sec.',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': None,
#                   'name': 'Ms. Ashlie  Thorburn',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'VP & Controller',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': None,
#                   'name': 'Mr. Mike  Eiselein',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'VP & GM',
#                   'total_compensation': 0}],
#   'indicators': [],
#   'securities': [{'code': 'HYMC',
#                   'currency_code': 'USD',
#                   'cusip': 'NA',
#                   'exchange': ' NASDAQ Exchnage',
#                   'exchange_id': 75,
#                   'isin': 'US44862P1093',
#                   'securities_type': 'Common Stock'}]},
#  {'all_executives': [{'bonus': 0,
#                       'dob': '1965-01-01',
#                       'name': 'Mr. John A. Hayes',
#                       'non_equity_incentives': 3902076,
#                       'option_awards': 2800000,
#                       'other_comp': 67359,
#                       'pension_and_deferred': 73183,
#                       'salary': 1299013,
#                       'stock_awards': 2800014,
#                       'title': 'Chairman, Pres & CEO',
#                       'total_compensation': 10941645},
#                      {'bonus': 0,
#                       'dob': '1966-01-01',
#                       'name': 'Mr. Mark J. Costa',
#                       'non_equity_incentives': 1540625,
#                       'option_awards': 2946429,
#                       'other_comp': 373043,
#                       'pension_and_deferred': 186226,
#                       'salary': 1226110,
#                       'stock_awards': 9646050,
#                       'title': 'Chairman & CEO',
#                       'total_compensation': 15918483},
#                      {'bonus': 0,
#                       'dob': '1962-01-01',
#                       'name': 'Mr. Edward L. Doheny II',
#                       'non_equity_incentives': 0,
#                       'option_awards': 0,
#                       'other_comp': 59118,
#                       'pension_and_deferred': 0,
#                       'salary': 1150000,
#                       'stock_awards': 7725109,
#                       'title': 'CEO, Pres & Director',
#                       'total_compensation': 8934227},
#                      {'bonus': 0,
#                       'dob': '1962-01-01',
#                       'name': 'Mr. Andreas  Fibig',
#                       'non_equity_incentives': 2634583,
#                       'option_awards': 0,
#                       'other_comp': 491396,
#                       'pension_and_deferred': 0,
#                       'salary': 1300000,
#                       'stock_awards': 4095961,
#                       'title': 'Chairman & CEO',
#                       'total_compensation': 8521940},
#                      {'bonus': 0,
#                       'dob': '1959-01-01',
#                       'name': 'Mr. Douglas M. Baker Jr.',
#                       'non_equity_incentives': 2284000,
#                       'option_awards': 5328337,
#                       'other_comp': 254004,
#                       'pension_and_deferred': 0,
#                       'salary': 1278125,
#                       'stock_awards': 5219567,
#                       'title': 'Chairman & CEO',
#                       'total_compensation': 14364033},
#                      {'bonus': 0,
#                       'dob': '1961-01-01',
#                       'name': "Mr. James C. O'Rourke P.Eng.",
#                       'non_equity_incentives': 2978300,
#                       'option_awards': 0,
#                       'other_comp': 769009,
#                       'pension_and_deferred': 0,
#                       'salary': 1178750,
#                       'stock_awards': 5599995,
#                       'title': 'CEO, Pres & Director',
#                       'total_compensation': 10526054}],
#   'company_detail': [{'address': 'Millenium Tower, Tel Aviv, Israel, 61070',
#                       'company_name': 'ICL Group Ltd',
#                       'company_pulse': 0.47390107422969163,
#                       'description': 'ICL Group Ltd, together with its '
#                                      'subsidiaries, operates as a specialty '
#                                      'minerals and chemicals company '
#                                      'worldwide. It operates in four segments: '
#                                      'Industrial Products, Potash, Phosphate '
#                                      'Solutions, and Innovative Ag Solutions '
#                                      '(IAS). The Industrial Products segment '
#                                      'produces bromine out of a solution that '
#                                      'is a by-product of the potash production '
#                                      'process, as well as bromine-based '
#                                      'compounds; produces various grades of '
#                                      'potash, salt, magnesium chloride, and '
#                                      'magnesia products; and produces and '
#                                      'markets phosphorous-based flame '
#                                      'retardants and other phosphorus-based '
#                                      'products. The Potash segment extracts '
#                                      'potash from the Dead Sea; mines and '
#                                      'produces potash and salt; produces '
#                                      'Polysulphate; produces, markets, and '
#                                      'sells magnesium and magnesium alloys, as '
#                                      'well as related by-products, including '
#                                      'chlorine and sylvinite; and sells salt. '
#                                      'The Phosphate Solutions segment produces '
#                                      'specialty products; produces and markets '
#                                      'phosphate-based fertilizers, as well as '
#                                      'sulphuric acid, green phosphoric acid, '
#                                      'and phosphate fertilizers; and '
#                                      'manufactures thermal phosphoric acid for '
#                                      'various industrial end markets, such as '
#                                      'oral care, cleaning products, paints and '
#                                      'coatings, water treatment, asphalt '
#                                      'modification, construction, and metal '
#                                      'treatment. It also develops and produces '
#                                      'functional food ingredients and '
#                                      'phosphate additives for use in the '
#                                      'processed meat, poultry, seafood, dairy, '
#                                      'beverage, and baked goods markets; and '
#                                      'produces milk and whey proteins for the '
#                                      'food ingredients industry. The IAS '
#                                      'segment develops, manufactures, markets, '
#                                      'and sells fertilizers based primarily on '
#                                      'nitrogen, potash, and phosphate, '
#                                      'including water soluble specialty, '
#                                      'liquid, soluble, and controlled-release '
#                                      'fertilizers. The company sells its '
#                                      'products through marketing companies, '
#                                      'agents, and distributors. The company '
#                                      'was formerly known as Israel Chemicals '
#                                      'Ltd. and changed its name to ICL Group '
#                                      'Ltd in May 2020. ICL Group Ltd was '
#                                      'founded in 1968 and is headquartered in '
#                                      'Tel Aviv, Israel.',
#                       'esg_beta': None,
#                       'esg_beta_tseries': None,
#                       'gicSector': 'Materials',
#                       'gicSubIndustry': 'Fertilizers & Agricultural Chemicals',
#                       'id': 194060,
#                       'pos_neg_ratio': [{'sentiment_rank': 'negative',
#                                          'total': 7},
#                                         {'sentiment_rank': 'positive',
#                                          'total': 78}],
#                       'url': 'http://www.icl-group.com'}],
#   'executives': [{'bonus': 0,
#                   'dob': '1964-01-01',
#                   'name': 'Mr. Raviv  Zoller',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Pres & CEO',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1968-01-01',
#                   'name': 'Mr. Kobi  Altman',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Chief Financial Officer',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1969-01-01',
#                   'name': 'Mr. Yoav  Doppelt',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Exec. Chairman',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1968-01-01',
#                   'name': 'Mr. Nitzan  Moshe',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Exec. VP of Global Operations',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1968-01-01',
#                   'name': 'Mr. Anantha N. Desikan',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Exec. VP and Chief Innovation & Technology Officer',
#                   'total_compensation': 0}],
#   'indicators': [{'Adult Activity': 'No',
#                   'Alcohol': 'No',
#                   'Animal Testing': 'No',
#                   'Catholic Values': 'No',
#                   'Clean Oceans': '',
#                   'Coal': 'No',
#                   'Controversial Weapons': 'No',
#                   'Deforestation': '',
#                   'Deforestation Financing': '',
#                   'Fur & Leather': 'No',
#                   'GMO': 'No',
#                   'Gambling': 'No',
#                   'Gender Equality': 'Yes',
#                   'Innovation': '',
#                   'Military Contracts': 'No',
#                   'Nuclear': 'No',
#                   'Oil & Gas': '',
#                   'Palm Oil': 'No',
#                   'Pesticides': 'No',
#                   'Prison Industry': '',
#                   'Renewable Energy': '',
#                   'Small Arms': 'No',
#                   'Tobacco': 'No'}],
#   'securities': [{'code': 'ICL',
#                   'currency_code': 'USD',
#                   'cusip': '465036200',
#                   'exchange': 'New York Stock Exchange',
#                   'exchange_id': 69,
#                   'isin': 'US4650471083',
#                   'securities_type': 'Common Stock'},
#                  {'code': 'ICL',
#                   'currency_code': 'ILS',
#                   'cusip': '',
#                   'exchange': 'Tel Aviv Exchange',
#                   'exchange_id': 32,
#                   'isin': 'IL0002810146',
#                   'securities_type': 'Common Stock'}]},
#  {'all_executives': [{'bonus': 0,
#                       'dob': '1965-01-01',
#                       'name': 'Mr. John A. Hayes',
#                       'non_equity_incentives': 3902076,
#                       'option_awards': 2800000,
#                       'other_comp': 67359,
#                       'pension_and_deferred': 73183,
#                       'salary': 1299013,
#                       'stock_awards': 2800014,
#                       'title': 'Chairman, Pres & CEO',
#                       'total_compensation': 10941645},
#                      {'bonus': 0,
#                       'dob': '1966-01-01',
#                       'name': 'Mr. Mark J. Costa',
#                       'non_equity_incentives': 1540625,
#                       'option_awards': 2946429,
#                       'other_comp': 373043,
#                       'pension_and_deferred': 186226,
#                       'salary': 1226110,
#                       'stock_awards': 9646050,
#                       'title': 'Chairman & CEO',
#                       'total_compensation': 15918483},
#                      {'bonus': 0,
#                       'dob': '1962-01-01',
#                       'name': 'Mr. Edward L. Doheny II',
#                       'non_equity_incentives': 0,
#                       'option_awards': 0,
#                       'other_comp': 59118,
#                       'pension_and_deferred': 0,
#                       'salary': 1150000,
#                       'stock_awards': 7725109,
#                       'title': 'CEO, Pres & Director',
#                       'total_compensation': 8934227},
#                      {'bonus': 0,
#                       'dob': '1962-01-01',
#                       'name': 'Mr. Andreas  Fibig',
#                       'non_equity_incentives': 2634583,
#                       'option_awards': 0,
#                       'other_comp': 491396,
#                       'pension_and_deferred': 0,
#                       'salary': 1300000,
#                       'stock_awards': 4095961,
#                       'title': 'Chairman & CEO',
#                       'total_compensation': 8521940},
#                      {'bonus': 0,
#                       'dob': '1959-01-01',
#                       'name': 'Mr. Douglas M. Baker Jr.',
#                       'non_equity_incentives': 2284000,
#                       'option_awards': 5328337,
#                       'other_comp': 254004,
#                       'pension_and_deferred': 0,
#                       'salary': 1278125,
#                       'stock_awards': 5219567,
#                       'title': 'Chairman & CEO',
#                       'total_compensation': 14364033},
#                      {'bonus': 0,
#                       'dob': '1961-01-01',
#                       'name': "Mr. James C. O'Rourke P.Eng.",
#                       'non_equity_incentives': 2978300,
#                       'option_awards': 0,
#                       'other_comp': 769009,
#                       'pension_and_deferred': 0,
#                       'salary': 1178750,
#                       'stock_awards': 5599995,
#                       'title': 'CEO, Pres & Director',
#                       'total_compensation': 10526054}],
#   'company_detail': [{'address': '75/102, Ocean Tower 2, Bangkok, Thailand, '
#                                  '10110',
#                       'company_name': 'Indorama Ventures Public Company '
#                                       'Limited',
#                       'company_pulse': 0.36554597701149427,
#                       'description': 'Indorama Ventures Public Company Limited '
#                                      'produces and distributes polyethylene '
#                                      'terephthalate (PET), purified '
#                                      'terephthalic acid (PTA), paraxylene, '
#                                      'isophthalic acid, ethylene oxide and '
#                                      'ethylene glycol, naphthalene '
#                                      'dicarboxylate, polyester fibers and '
#                                      'yarns, and wool products. It operates in '
#                                      'five segments: Integrated PET, Fibers, '
#                                      'Packaging, Integrated Oxides and '
#                                      'Derivatives, and Specialty Chemicals. '
#                                      'The company produces hot-fill, high and '
#                                      'low intrinsic viscosity, quick heat and '
#                                      'general grade PET products for use in as '
#                                      'a raw material in the manufacture of '
#                                      'bottles, sheets, films, fibers, '
#                                      'filaments, and other specialty products; '
#                                      'and packaging materials, such as molding '
#                                      'bottles, bottle caps, and bottles. It '
#                                      'also provides monoethylene glycol, '
#                                      'diethylene glycol, triethylene glycol, '
#                                      'and purified ethylene oxide; and '
#                                      'polyester, rayon, nylon, polypropylene, '
#                                      'composites, and worsted wool fibers. In '
#                                      'addition, the company offers fibers, '
#                                      'including polyester fibers and yarns, '
#                                      'polyolefin fibers, bicomponent fibers, '
#                                      'and other fibers for home, apparel, '
#                                      'hygiene and medical, automotive, and '
#                                      'industrial/technical markets; Further, '
#                                      'it provides recycled products, such as '
#                                      'bottle flakes, recycled PET, and '
#                                      'recycled fibers; and wool products, '
#                                      'including weaving, stretch, knitting, '
#                                      'environmentally-friendly, compact, and '
#                                      'special end use yarns. The company '
#                                      'operates in Thailand, North America, '
#                                      'Europe, and internationally. The company '
#                                      'is headquartered in Bangkok, Thailand. '
#                                      'Indorama Ventures Public Company Limited '
#                                      'is a subsidiary of Indorama Resources '
#                                      'Limited.',
#                       'esg_beta': None,
#                       'esg_beta_tseries': None,
#                       'gicSector': 'Materials',
#                       'gicSubIndustry': 'Commodity Chemicals',
#                       'id': 202406,
#                       'pos_neg_ratio': [{'sentiment_rank': 'negative',
#                                          'total': 5},
#                                         {'sentiment_rank': 'positive',
#                                          'total': 24}],
#                       'url': 'http://www.indoramaventures.com'}],
#   'executives': [{'bonus': 0,
#                   'dob': '1959-01-01',
#                   'name': 'Mr. Aloke  Lohia',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Vice Chairman & Group CEO',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1969-01-01',
#                   'name': 'Mr. Sanjay  Ahuja',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'CFO & Exec. Director',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1965-01-01',
#                   'name': 'Ms. Suchitra  Lohia',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Exec. Director',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1958-01-01',
#                   'name': 'Mr. Dilip Kumar Agarwal',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Exec. Director and CEO of Feedstock & PET Bus.',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1953-01-01',
#                   'name': 'Mr. Udey Paul Singh Gill',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Exec. Director & CEO of Fibers Bus.',
#                   'total_compensation': 0}],
#   'indicators': [],
#   'securities': [{'code': 'INDOY',
#                   'currency_code': 'USD',
#                   'cusip': '',
#                   'exchange': ' Pink',
#                   'exchange_id': 72,
#                   'isin': '',
#                   'securities_type': 'Common Stock'},
#                  {'code': 'I93',
#                   'currency_code': 'EUR',
#                   'cusip': '',
#                   'exchange': 'Frankfurt Exchange',
#                   'exchange_id': 12,
#                   'isin': '',
#                   'securities_type': 'Common Stock'},
#                  {'code': 'IVL',
#                   'currency_code': 'THB',
#                   'cusip': '',
#                   'exchange': 'Thailand Exchange',
#                   'exchange_id': 44,
#                   'isin': 'TH1027010004',
#                   'securities_type': 'Common Stock'}]},
#  {'all_executives': [{'bonus': 0,
#                       'dob': '1965-01-01',
#                       'name': 'Mr. John A. Hayes',
#                       'non_equity_incentives': 3902076,
#                       'option_awards': 2800000,
#                       'other_comp': 67359,
#                       'pension_and_deferred': 73183,
#                       'salary': 1299013,
#                       'stock_awards': 2800014,
#                       'title': 'Chairman, Pres & CEO',
#                       'total_compensation': 10941645},
#                      {'bonus': 0,
#                       'dob': '1966-01-01',
#                       'name': 'Mr. Mark J. Costa',
#                       'non_equity_incentives': 1540625,
#                       'option_awards': 2946429,
#                       'other_comp': 373043,
#                       'pension_and_deferred': 186226,
#                       'salary': 1226110,
#                       'stock_awards': 9646050,
#                       'title': 'Chairman & CEO',
#                       'total_compensation': 15918483},
#                      {'bonus': 0,
#                       'dob': '1962-01-01',
#                       'name': 'Mr. Edward L. Doheny II',
#                       'non_equity_incentives': 0,
#                       'option_awards': 0,
#                       'other_comp': 59118,
#                       'pension_and_deferred': 0,
#                       'salary': 1150000,
#                       'stock_awards': 7725109,
#                       'title': 'CEO, Pres & Director',
#                       'total_compensation': 8934227},
#                      {'bonus': 0,
#                       'dob': '1962-01-01',
#                       'name': 'Mr. Andreas  Fibig',
#                       'non_equity_incentives': 2634583,
#                       'option_awards': 0,
#                       'other_comp': 491396,
#                       'pension_and_deferred': 0,
#                       'salary': 1300000,
#                       'stock_awards': 4095961,
#                       'title': 'Chairman & CEO',
#                       'total_compensation': 8521940},
#                      {'bonus': 0,
#                       'dob': '1959-01-01',
#                       'name': 'Mr. Douglas M. Baker Jr.',
#                       'non_equity_incentives': 2284000,
#                       'option_awards': 5328337,
#                       'other_comp': 254004,
#                       'pension_and_deferred': 0,
#                       'salary': 1278125,
#                       'stock_awards': 5219567,
#                       'title': 'Chairman & CEO',
#                       'total_compensation': 14364033},
#                      {'bonus': 0,
#                       'dob': '1961-01-01',
#                       'name': "Mr. James C. O'Rourke P.Eng.",
#                       'non_equity_incentives': 2978300,
#                       'option_awards': 0,
#                       'other_comp': 769009,
#                       'pension_and_deferred': 0,
#                       'salary': 1178750,
#                       'stock_awards': 5599995,
#                       'title': 'CEO, Pres & Director',
#                       'total_compensation': 10526054}],
#   'company_detail': [{'address': '5255 Virginia Avenue, North Charleston, SC, '
#                                  'United States, 29406',
#                       'company_name': 'Ingevity Corporation',
#                       'company_pulse': 0.4607875724637682,
#                       'description': 'Ingevity Corporation manufactures and '
#                                      'sells specialty chemicals and activated '
#                                      'carbon materials in North America, '
#                                      'Europe, the Asia-Pacific, and '
#                                      'internationally. The company operates '
#                                      'through two segments, Performance '
#                                      'Materials and Performance Chemicals. The '
#                                      'Performance Materials segment engineers, '
#                                      'manufactures, and sells hardwood-based '
#                                      'and chemically activated carbon products '
#                                      'primarily for use in gasoline vapor '
#                                      'emission control systems in cars, '
#                                      'trucks, motorcycles, and boats. This '
#                                      'segment also produces other activated '
#                                      'carbon products for use in various '
#                                      'applications, including food, water, '
#                                      'beverage, and chemical purification. The '
#                                      'Performance Chemicals segment develops, '
#                                      'manufactures, and sells a range of '
#                                      'specialty chemicals derived from '
#                                      'co-products of the kraft pulping process '
#                                      'and caprolactone monomers. This '
#                                      "segment's products are used in various "
#                                      'applications comprising pavement '
#                                      'preservation, pavement adhesion '
#                                      'promotion, and warm mix paving; oil well '
#                                      'service additives, oil production, and '
#                                      'downstream application chemicals; '
#                                      'printing inks, adhesives, agrochemicals, '
#                                      'lubricants, and industrial '
#                                      'intermediates; and coatings, resins, '
#                                      'elastomers, and bio-plastics. Ingevity '
#                                      'Corporation was incorporated in 2015 and '
#                                      'is headquartered in North Charleston, '
#                                      'South Carolina.',
#                       'esg_beta': None,
#                       'esg_beta_tseries': None,
#                       'gicSector': 'Materials',
#                       'gicSubIndustry': 'Specialty Chemicals',
#                       'id': 206642,
#                       'pos_neg_ratio': [{'sentiment_rank': 'negative',
#                                          'total': 6},
#                                         {'sentiment_rank': 'positive',
#                                          'total': 40}],
#                       'url': 'http://www.ingevity.com'}],
#   'executives': [{'bonus': 0,
#                   'dob': '1947-01-01',
#                   'name': 'Mr. Richard B. Kelson',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Chairman and Interim Pres & CEO',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1967-01-01',
#                   'name': 'Mr. John C. Fortson',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Exec. VP, CFO & Treasurer',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1958-01-01',
#                   'name': 'Ms. Katherine Pryor Burgeson',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Exec. VP, Gen. Counsel & Sec.',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1966-01-01',
#                   'name': 'Mr. Stuart Edward Woodcock Jr.',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Exec. VP & Pres of Performance Materials',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1961-01-01',
#                   'name': 'Mr. Michael P. Smith',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Exec. VP and Pres of Performance Chemicals, '
#                            'Strategy & Bus. Devel.',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1967-01-01',
#                   'name': 'Mr. John C. Fortson',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Pres, CEO & Director',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1958-01-01',
#                   'name': 'Ms. Mary Dean Hall',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Exec. VP & CFO',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1971-01-01',
#                   'name': 'Ms. Stacy Lancaster Cozad',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Exec. VP, Gen. Counsel & Sec.',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1981-01-01',
#                   'name': 'Mr. Phillip John Platt',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Chief Accounting Officer, Corp. Controller & VP of '
#                            'Financial Planning',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': None,
#                   'name': 'Mr. Daniel  Gallagher',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'VP of Investor Relations',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': None,
#                   'name': 'John  Nypaver',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'VP of Treasurer & Investor Relations',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': None,
#                   'name': 'Ms. Christine  Stunyo',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Sr. VP & Chief HR Officer',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1963-01-01',
#                   'name': 'Mr. Richard  White',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Sr. VP of Performance Chemicals and Pres of '
#                            'Industrial Specialties & Pavement Technologies',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': None,
#                   'name': 'Mr. Erik  Ripple',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Sr. VP and Chief Growth & Innovation Officer',
#                   'total_compensation': 0}],
#   'indicators': [{'Adult Activity': None,
#                   'Alcohol': None,
#                   'Animal Testing': None,
#                   'Catholic Values': None,
#                   'Clean Oceans': '',
#                   'Coal': None,
#                   'Controversial Weapons': None,
#                   'Deforestation': '',
#                   'Deforestation Financing': '',
#                   'Fur & Leather': None,
#                   'GMO': None,
#                   'Gambling': None,
#                   'Gender Equality': '',
#                   'Innovation': '',
#                   'Military Contracts': None,
#                   'Nuclear': None,
#                   'Oil & Gas': '',
#                   'Palm Oil': None,
#                   'Pesticides': None,
#                   'Prison Industry': '',
#                   'Renewable Energy': '',
#                   'Small Arms': None,
#                   'Tobacco': None}],
#   'securities': [{'code': 'NGVT',
#                   'currency_code': 'USD',
#                   'cusip': '45688C107',
#                   'exchange': 'New York Stock Exchange',
#                   'exchange_id': 69,
#                   'isin': 'US45688C1071',
#                   'securities_type': 'Common Stock'},
#                  {'code': 'IGX',
#                   'currency_code': 'EUR',
#                   'cusip': 'NA',
#                   'exchange': 'Frankfurt Exchange',
#                   'exchange_id': 12,
#                   'isin': 'US45688C1071',
#                   'securities_type': 'Common Stock'}]},
#  {'all_executives': [{'bonus': 0,
#                       'dob': '1965-01-01',
#                       'name': 'Mr. John A. Hayes',
#                       'non_equity_incentives': 3902076,
#                       'option_awards': 2800000,
#                       'other_comp': 67359,
#                       'pension_and_deferred': 73183,
#                       'salary': 1299013,
#                       'stock_awards': 2800014,
#                       'title': 'Chairman, Pres & CEO',
#                       'total_compensation': 10941645},
#                      {'bonus': 0,
#                       'dob': '1966-01-01',
#                       'name': 'Mr. Mark J. Costa',
#                       'non_equity_incentives': 1540625,
#                       'option_awards': 2946429,
#                       'other_comp': 373043,
#                       'pension_and_deferred': 186226,
#                       'salary': 1226110,
#                       'stock_awards': 9646050,
#                       'title': 'Chairman & CEO',
#                       'total_compensation': 15918483},
#                      {'bonus': 0,
#                       'dob': '1962-01-01',
#                       'name': 'Mr. Edward L. Doheny II',
#                       'non_equity_incentives': 0,
#                       'option_awards': 0,
#                       'other_comp': 59118,
#                       'pension_and_deferred': 0,
#                       'salary': 1150000,
#                       'stock_awards': 7725109,
#                       'title': 'CEO, Pres & Director',
#                       'total_compensation': 8934227},
#                      {'bonus': 0,
#                       'dob': '1962-01-01',
#                       'name': 'Mr. Andreas  Fibig',
#                       'non_equity_incentives': 2634583,
#                       'option_awards': 0,
#                       'other_comp': 491396,
#                       'pension_and_deferred': 0,
#                       'salary': 1300000,
#                       'stock_awards': 4095961,
#                       'title': 'Chairman & CEO',
#                       'total_compensation': 8521940},
#                      {'bonus': 0,
#                       'dob': '1959-01-01',
#                       'name': 'Mr. Douglas M. Baker Jr.',
#                       'non_equity_incentives': 2284000,
#                       'option_awards': 5328337,
#                       'other_comp': 254004,
#                       'pension_and_deferred': 0,
#                       'salary': 1278125,
#                       'stock_awards': 5219567,
#                       'title': 'Chairman & CEO',
#                       'total_compensation': 14364033},
#                      {'bonus': 0,
#                       'dob': '1961-01-01',
#                       'name': "Mr. James C. O'Rourke P.Eng.",
#                       'non_equity_incentives': 2978300,
#                       'option_awards': 0,
#                       'other_comp': 769009,
#                       'pension_and_deferred': 0,
#                       'salary': 1178750,
# ...
#                                      'South America, and internationally. It '
#                                      'extracts raw materials, including potash '
#                                      'and bromine from Dead Sea; and specialty '
#                                      'phosphates from phosphate rock mines. '
#                                      'The company offers bromine-based flame '
#                                      'retardants and industrial solutions; '
#                                      'elemental bromine; bromine compounds; '
#                                      'magnesium; phosphorous-based industrial '
#                                      'compounds; specialty agriculture '
#                                      'products; phosphate fertilizers; green '
#                                      'phosphoric acid; phosphorus-based flame '
#                                      'retardants; clear brine fluids; calcium '
#                                      'products; brominated biocides; organic '
#                                      'and inorganic bromides; potassium '
#                                      'chloride; magnesium dichloride; and '
#                                      'magnesia products. It also provide '
#                                      'specialty fertilizers, including soluble '
#                                      'fertilizers, which includes '
#                                      'water-soluble straights and '
#                                      'water-soluble NPK; controlled release '
#                                      'fertilizers; and liquid NPK fertilizers. '
#                                      'In addition, the company produces fuel '
#                                      'products; raw materials for the '
#                                      'petrochemical industry; materials for '
#                                      'the plastics industry; and oils, waxes, '
#                                      'and related products, as well as '
#                                      'provides power and water, including '
#                                      'steam services to various industries in '
#                                      'Haifa. Its products are primarily used '
#                                      'in the areas of agriculture, '
#                                      'electronics, construction, automotive, '
#                                      'oil drilling, food, furniture, '
#                                      'pharmaceutical, textile, water '
#                                      'treatment, metal treatment, oral care, '
#                                      'carbonated drinks, asphalt modification, '
#                                      'paints and coatings, and other '
#                                      'industries. The company was founded in '
#                                      '1968 and is based in Tel Aviv, Israel.',
#                       'esg_beta': None,
#                       'esg_beta_tseries': None,
#                       'gicSector': 'Materials',
#                       'gicSubIndustry': 'Fertilizers & Agricultural Chemicals',
#                       'id': 194047,
#                       'pos_neg_ratio': [{'sentiment_rank': 'positive',
#                                          'total': 2}],
#                       'url': 'http://www.israelcorp.com'}],
#   'executives': [{'bonus': 0,
#                   'dob': '1976-01-01',
#                   'name': 'Mr. Sagi  Kabala',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Chief Financial Officer',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1972-01-01',
#                   'name': 'Ms. Maya  Alschich-Kaplan',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Exec. VP, Gen. Counsel & Company Sec.',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1945-01-01',
#                   'name': 'Mr. Ovadia  Eli',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Chairman of ORL',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1959-01-01',
#                   'name': 'Mr. Charles Michael Weidhas',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'CEO & Pres of ICL Industrial Products',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1950-01-01',
#                   'name': 'Mr. Asher  Grinbaum',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'COO of Israel Chemicals Ltd. and Exec. VP of '
#                            'Israel Chemicals Ltd.',
#                   'total_compensation': 0}],
#   'indicators': [],
#   'securities': [{'code': 'IRLCF',
#                   'currency_code': 'USD',
#                   'cusip': '',
#                   'exchange': ' Pink',
#                   'exchange_id': 72,
#                   'isin': '',
#                   'securities_type': 'Common Stock'},
#                  {'code': 'ILCO',
#                   'currency_code': 'ILS',
#                   'cusip': '',
#                   'exchange': 'Tel Aviv Exchange',
#                   'exchange_id': 32,
#                   'isin': 'IL0005760173',
#                   'securities_type': 'Common Stock'}]},
#  {'all_executives': [{'bonus': 0,
#                       'dob': '1965-01-01',
#                       'name': 'Mr. John A. Hayes',
#                       'non_equity_incentives': 3902076,
#                       'option_awards': 2800000,
#                       'other_comp': 67359,
#                       'pension_and_deferred': 73183,
#                       'salary': 1299013,
#                       'stock_awards': 2800014,
#                       'title': 'Chairman, Pres & CEO',
#                       'total_compensation': 10941645},
#                      {'bonus': 0,
#                       'dob': '1966-01-01',
#                       'name': 'Mr. Mark J. Costa',
#                       'non_equity_incentives': 1540625,
#                       'option_awards': 2946429,
#                       'other_comp': 373043,
#                       'pension_and_deferred': 186226,
#                       'salary': 1226110,
#                       'stock_awards': 9646050,
#                       'title': 'Chairman & CEO',
#                       'total_compensation': 15918483},
#                      {'bonus': 0,
#                       'dob': '1962-01-01',
#                       'name': 'Mr. Edward L. Doheny II',
#                       'non_equity_incentives': 0,
#                       'option_awards': 0,
#                       'other_comp': 59118,
#                       'pension_and_deferred': 0,
#                       'salary': 1150000,
#                       'stock_awards': 7725109,
#                       'title': 'CEO, Pres & Director',
#                       'total_compensation': 8934227},
#                      {'bonus': 0,
#                       'dob': '1962-01-01',
#                       'name': 'Mr. Andreas  Fibig',
#                       'non_equity_incentives': 2634583,
#                       'option_awards': 0,
#                       'other_comp': 491396,
#                       'pension_and_deferred': 0,
#                       'salary': 1300000,
#                       'stock_awards': 4095961,
#                       'title': 'Chairman & CEO',
#                       'total_compensation': 8521940},
#                      {'bonus': 0,
#                       'dob': '1959-01-01',
#                       'name': 'Mr. Douglas M. Baker Jr.',
#                       'non_equity_incentives': 2284000,
#                       'option_awards': 5328337,
#                       'other_comp': 254004,
#                       'pension_and_deferred': 0,
#                       'salary': 1278125,
#                       'stock_awards': 5219567,
#                       'title': 'Chairman & CEO',
#                       'total_compensation': 14364033},
#                      {'bonus': 0,
#                       'dob': '1961-01-01',
#                       'name': "Mr. James C. O'Rourke P.Eng.",
#                       'non_equity_incentives': 2978300,
#                       'option_awards': 0,
#                       'other_comp': 769009,
#                       'pension_and_deferred': 0,
#                       'salary': 1178750,
#                       'stock_awards': 5599995,
#                       'title': 'CEO, Pres & Director',
#                       'total_compensation': 10526054}],
#   'company_detail': [{'address': '999 Canada Place, Vancouver, BC, Canada, V6C '
#                                  '3E1',
#                       'company_name': 'Ivanhoe Mines Ltd',
#                       'company_pulse': 0.31721250000000006,
#                       'description': 'Ivanhoe Mines Ltd. engages in the '
#                                      'exploration, development, and recovery '
#                                      'of minerals and precious metals located '
#                                      'primarily in Africa. The company '
#                                      'explores for platinum, palladium, '
#                                      'nickel, copper, gold, rhodium, zinc, '
#                                      'germanium, and lead deposits. Its '
#                                      'projects include the Platreef project '
#                                      'located in the Northern Limb of South '
#                                      "Africa's Bushveld Complex; the Kipushi "
#                                      "project located on the DRC's Copperbelt; "
#                                      'and the Kamoa-Kakula project located '
#                                      'within the Central African Copperbelt. '
#                                      'It also holds a 100% interest in the '
#                                      'Western Foreland exploration project '
#                                      'covering an area of approximately 2,550 '
#                                      'square kilometers located in the '
#                                      'Democratic Republic of Congo. The '
#                                      'company was formerly known as Ivanplats '
#                                      'Limited and changed its name to Ivanhoe '
#                                      'Mines Ltd. in August 2013. Ivanhoe Mines '
#                                      'Ltd. was incorporated in 1993 and is '
#                                      'headquartered in Vancouver, Canada.',
#                       'esg_beta': None,
#                       'esg_beta_tseries': None,
#                       'gicSector': 'Materials',
#                       'gicSubIndustry': 'Diversified Metals & Mining',
#                       'id': 206013,
#                       'pos_neg_ratio': [{'sentiment_rank': 'negative',
#                                          'total': 3},
#                                         {'sentiment_rank': 'positive',
#                                          'total': 11}],
#                       'url': 'http://www.ivanhoemines.com'}],
#   'executives': [{'bonus': 0,
#                   'dob': '1951-01-01',
#                   'name': 'Mr. Robert Martin  Friedland',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Founder & Exec. Co-Chairman',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1961-01-01',
#                   'name': 'Mr. Egizio  Bianchini',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Exec. Vice Chairman',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1977-01-01',
#                   'name': 'Ms. Martie  Cloete',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Pres & CFO',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': '1959-01-01',
#                   'name': 'Mr. Warwick P. Morley-Jepson',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'Exec. VP & COO',
#                   'total_compensation': 0},
#                  {'bonus': 0,
#                   'dob': None,
#                   'name': 'Ms. Mary A. Vincelli',
#                   'non_equity_incentives': 0,
#                   'option_awards': 0,
#                   'other_comp': 0,
#                   'pension_and_deferred': 0,
#                   'salary': 0,
#                   'stock_awards': 0,
#                   'title': 'VP of Compliance & Corp. Sec.',
#                   'total_compensation': 0}],
#   'indicators': [{'Adult Activity': None,
#                   'Alcohol': None,
#                   'Animal Testing': None,
#                   'Catholic Values': None,
#                   'Clean Oceans': '',
#                   'Coal': None,
#                   'Controversial Weapons': None,
#                   'Deforestation': '',
#                   'Deforestation Financing': '',
#                   'Fur & Leather': None,
#                   'GMO': None,
#                   'Gambling': None,
#                   'Gender Equality': '',
#                   'Innovation': '',
#                   'Military Contracts': None,
#                   'Nuclear': None,
#                   'Oil & Gas': '',
#                   'Palm Oil': None,
#                   'Pesticides': None,
#                   'Prison Industry': '',
#                   'Renewable Energy': '',
#                   'Small Arms': None,
#                   'Tobacco': None}],
#   'securities': [{'code': 'IVPAF',
#                   'currency_code': 'USD',
#                   'cusip': '',
#                   'exchange': ' OTC QX Exchange',
#                   'exchange_id': 78,
#                   'isin': '',
#                   'securities_type': 'Common Stock'},
#                  {'code': 'IVN',
#                   'currency_code': 'CAD',
#                   'cusip': '',
#                   'exchange': 'Toronto Exchange',
#                   'exchange_id': 3,
#                   'isin': 'CA46579R1047',
#                   'securities_type': 'Common Stock'},
#                  {'code': 'IYAA',
#                   'currency_code': 'EUR',
#                   'cusip': '',
#                   'exchange': 'Frankfurt Exchange',
#                   'exchange_id': 12,
#                   'isin': '',
#                   'securities_type': 'Common Stock'}]}]

# %%
print(type(dict_data))
# Out:
# <class 'list'>

# %%
print(type(api_data))
# Out:
# <class 'list'>

# %%
print(len(dict_data))
# Out:
# 10

# %%
print(len(api_data))
# Out:
# 10

# %%
#pip install flatten_json

# %%
# see https://github.com/amirziai/flatten
#from flatten_json import flatten

# %%
#df_flatten = pd.DataFrame([flatten(dict_data)['id']])
#df_flatten

# %%
print(dict_data[0])
# Out:
# {'company_detail': [{'id': 243688, 'company_name': 'Hycroft Mining Holding Corporation', 'description': 'Hycroft Mining Holding Corporation, together with its subsidiaries, operates as a gold and silver development company in the United States. The company holds interests in the Hycroft mine that covers an area of approximately 70,671 acres located in the state of Nevada. As of December 31, 2021, its Hycroft mine had measured and indicated mineral resources of 9.6 million ounces of gold, and 446.0 million ounces of silver. Hycroft Mining Holding Corporation is headquartered in Winnemucca, Nevada.', 'gicSector': 'Materials', 'url': 'https://www.hycroftmining.com', 'address': 'Unit 1, Winnemucca, NV, United States, 89445', 'gicSubIndustry': 'Gold', 'company_pulse': -0.08954375, 'pos_neg_ratio': [{'sentiment_rank': 'negative', 'total': 7}, {'sentiment_rank': 'positive', 'total': 9}], 'esg_beta': None, 'esg_beta_tseries': None}], 'securities': [{'exchange': ' NASDAQ Exchnage', 'exchange_id': 75, 'code': 'HYMC', 'isin': 'US44862P1093', 'cusip': 'NA', 'securities_type': 'Common Stock', 'currency_code': 'USD'}], 'executives': [{'name': 'Dr. Diane Renee Garrett Eng., M.A., M.S., Mineral Eco, Ph.D.', 'title': 'Pres, CEO & Director', 'dob': '1960-01-01', 'salary': 0, 'bonus': 0, 'stock_awards': 0, 'option_awards': 0, 'non_equity_incentives': 0, 'pension_and_deferred': 0, 'other_comp': 0, 'total_compensation': 0}, {'name': 'Mr. Stanton K. Rideout CPA, CPA, MBA', 'title': 'Exec. VP & CFO', 'dob': '1959-01-01', 'salary': 0, 'bonus': 0, 'stock_awards': 0, 'option_awards': 0, 'non_equity_incentives': 0, 'pension_and_deferred': 0, 'other_comp': 0, 'total_compensation': 0}, {'name': 'Nigel  Bain', 'title': 'VP of Operations', 'dob': None, 'salary': 0, 'bonus': 0, 'stock_awards': 0, 'option_awards': 0, 'non_equity_incentives': 0, 'pension_and_deferred': 0, 'other_comp': 0, 'total_compensation': 0}, {'name': 'Mr. Alex  Davidson', 'title': 'VP of Exploration', 'dob': None, 'salary': 0, 'bonus': 0, 'stock_awards': 0, 'option_awards': 0, 'non_equity_incentives': 0, 'pension_and_deferred': 0, 'other_comp': 0, 'total_compensation': 0}, {'name': 'David S. Stone', 'title': 'Corp. Sec.', 'dob': None, 'salary': 0, 'bonus': 0, 'stock_awards': 0, 'option_awards': 0, 'non_equity_incentives': 0, 'pension_and_deferred': 0, 'other_comp': 0, 'total_compensation': 0}, {'name': 'Ms. Ashlie  Thorburn', 'title': 'VP & Controller', 'dob': None, 'salary': 0, 'bonus': 0, 'stock_awards': 0, 'option_awards': 0, 'non_equity_incentives': 0, 'pension_and_deferred': 0, 'other_comp': 0, 'total_compensation': 0}, {'name': 'Mr. Mike  Eiselein', 'title': 'VP & GM', 'dob': None, 'salary': 0, 'bonus': 0, 'stock_awards': 0, 'option_awards': 0, 'non_equity_incentives': 0, 'pension_and_deferred': 0, 'other_comp': 0, 'total_compensation': 0}], 'all_executives': [{'name': 'Mr. John A. Hayes', 'title': 'Chairman, Pres & CEO', 'dob': '1965-01-01', 'salary': 1299013, 'bonus': 0, 'stock_awards': 2800014, 'option_awards': 2800000, 'non_equity_incentives': 3902076, 'pension_and_deferred': 73183, 'other_comp': 67359, 'total_compensation': 10941645}, {'name': 'Mr. Mark J. Costa', 'title': 'Chairman & CEO', 'dob': '1966-01-01', 'salary': 1226110, 'bonus': 0, 'stock_awards': 9646050, 'option_awards': 2946429, 'non_equity_incentives': 1540625, 'pension_and_deferred': 186226, 'other_comp': 373043, 'total_compensation': 15918483}, {'name': 'Mr. Edward L. Doheny II', 'title': 'CEO, Pres & Director', 'dob': '1962-01-01', 'salary': 1150000, 'bonus': 0, 'stock_awards': 7725109, 'option_awards': 0, 'non_equity_incentives': 0, 'pension_and_deferred': 0, 'other_comp': 59118, 'total_compensation': 8934227}, {'name': 'Mr. Andreas  Fibig', 'title': 'Chairman & CEO', 'dob': '1962-01-01', 'salary': 1300000, 'bonus': 0, 'stock_awards': 4095961, 'option_awards': 0, 'non_equity_incentives': 2634583, 'pension_and_deferred': 0, 'other_comp': 491396, 'total_compensation': 8521940}, {'name': 'Mr. Douglas M. Baker Jr ...

# %%
# see https://stackoverflow.com/questions/47242845/pandas-json-normalize-with-very-nested-json


df_detail2 = pd.json_normalize(dict_data, 'company_detail')
df_detail2
# Out:
#        id                              company_name  \
# 0  243688        Hycroft Mining Holding Corporation
# 1  194060                             ICL Group Ltd
# 2  202406  Indorama Ventures Public Company Limited
# 3  206642                      Ingevity Corporation
# 4  206404                              Innospec Inc
# 5  189956    International Flavors & Fragrances Inc
# 6  190398               International Paper Company
# 7  245305                       Intrepid Potash Inc
# 8  194047                    Israel Corporation Ltd
# 9  206013                         Ivanhoe Mines Ltd
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 description  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Hycroft Mining Holding Corporation, together with its subsidiaries, operates as a gold and silver development company in the United States. The company holds interests in the Hycroft mine that covers an area of approximately 70,671 acres located in the state of Nevada. As of December 31, 2021, its Hycroft mine had measured and indicated mineral resources of 9.6 million ounces of gold, and 446.0 million ounces of silver. Hycroft Mining Holding Corporation is headquartered in Winnemucca, Nevada.
# 1  ICL Group Ltd, together with its subsidiaries, operates as a specialty minerals and chemicals company worldwide. It operates in four segments: Industrial Products, Potash, Phosphate Solutions, and Innovative Ag Solutions (IAS). The Industrial Products segment produces bromine out of a solution that is a by-product of the potash production process, as well as bromine-based compounds; produces various grades of potash, salt, magnesium chloride, and magnesia products; and produces and markets phosphorous-based flame retardants and other phosphorus-based products. The Potash segment extracts potash from the Dead Sea; mines and produces potash and salt; produces Polysulphate; produces, markets, and sells magnesium and magnesium alloys, as well as related by-products, including chlorine and sylvinite; and sells salt. The Phosphate Solutions segment produces specialty products; produces and markets phosphate-based fertilizers, as well as sulphuric acid, green phosphoric acid, and phosphate fertilizers; and manufactures thermal phosphoric acid for various industrial end markets, such as oral care, cleaning products, paints and coatings, water treatment, asphalt modification, construction, and metal treatment. It also develops and produces functional food ingredients and phosphate additives for use in the processed meat, poultry, seafood, dairy, beverage, and baked goods markets; and produces milk and whey proteins for the food ingredients industry. The IAS segment develops, manufactures, markets, and sells fertilizers based primarily on nitrogen, potash, and phosphate, including water soluble specialty, liquid, soluble, and controlled-release fertilizers. The company sells its products through marketing companies, agents, and distributors. The company was formerly known as Israel Chemicals Ltd. and changed its name to ICL Group Ltd in May 2020. ICL Group Ltd was founded in 1968 and is headquartered in Tel Aviv, Israel.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                Indorama Ventures Public Company Limited produces and distributes polyethylene terephthalate (PET), purified terephthalic acid (PTA), paraxylene, isophthalic acid, ethylene oxide and ethylene glycol, naphthalene dicarboxylate, polyester fibers and yarns, and wool products. It operates in five segments: Integrated PET, Fibers, Packaging, Integrated Oxides and Derivatives, and Specialty Chemicals. The company produces hot-fill, high and low intrinsic viscosity, quick heat and general grade PET products for use in as a raw material in the manufacture of bottles, sheets, films, fibers, filaments, and other specialty products; and packaging materials, such as molding bottles, bottle caps, and bottles. It also provides monoethylene glycol, diethylene glycol, triethylene glycol, and purified ethylene oxide; and polyester, rayon, nylon, polypropylene, composites, and worsted wool fibers. In addition, the company offers fibers, including polyester fibers and yarns, polyolefin fibers, bicomponent fibers, and other fibers for home, apparel, hygiene and medical, automotive, and industrial/technical markets; Further, it provides recycled products, such as bottle flakes, recycled PET, and recycled fibers; and wool products, including weaving, stretch, knitting, environmentally-friendly, compact, and special end use yarns. The company operates in Thailand, North America, Europe, and internationally. The company is headquartered in Bangkok, Thailand. Indorama Ventures Public Company Limited is a subsidiary of Indorama Resources Limited.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Ingevity Corporation manufactures and sells specialty chemicals and activated carbon materials in North America, Europe, the Asia-Pacific, and internationally. The company operates through two segments, Performance Materials and Performance Chemicals. The Performance Materials segment engineers, manufactures, and sells hardwood-based and chemically activated carbon products primarily for use in gasoline vapor emission control systems in cars, trucks, motorcycles, and boats. This segment also produces other activated carbon products for use in various applications, including food, water, beverage, and chemical purification. The Performance Chemicals segment develops, manufactures, and sells a range of specialty chemicals derived from co-products of the kraft pulping process and caprolactone monomers. This segment's products are used in various applications comprising pavement preservation, pavement adhesion promotion, and warm mix paving; oil well service additives, oil production, and downstream application chemicals; printing inks, adhesives, agrochemicals, lubricants, and industrial intermediates; and coatings, resins, elastomers, and bio-plastics. Ingevity Corporation was incorporated in 2015 and is headquartered in North Charleston, South Carolina.
# 4                                                                                                                                                                                                                                                                                                                                             Innospec Inc. develops, manufactures, blends, markets, and supplies specialty chemicals worldwide. It operates through four segments: Fuel Specialties, Performance Chemicals, Oilfield Services, and Octane Additives. The Fuel Specialties segment offers a range of specialty chemical products used as additives in various fuels. Its products are used in the operation of automotive, marine, and aviation engines; power station generators; and heating oil. The Performance Chemicals segment provides technology-based solutions for its customers' processes or products focused in the personal care, home care, agrochemical, and metal extraction markets. The Oilfield Services segment develops and markets products to prevent loss of mud in drilling operations; chemical solutions for fracturing, stimulation, and completion operations; and products for oil and gas production, which enable flow assurance and asset integrity. The Octane Additives segment produces and sells tetra ethyl lead (TEL) for use in automotive gasoline. This segment is also involved in environmental remediation business that manages the cleanup of redundant TEL facilities. The company sells its products primarily to oil and gas exploration and production companies, oil refineries, fuel manufacturers and users, personal care and home care companies, formulators of agrochemical and metal extraction preparations, and other chemical and industrial companies. The company was formerly known as Octel Corp. and changed its name to Innospec Inc. in January 2006. Innospec Inc. was founded in 1938 and is headquartered in Englewood, Colorado.
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                     International Flavors & Fragrances Inc., together with its subsidiaries, manufactures flavors and fragrances for use in various consumer products. It operates through two segments, Taste and Scent. The Taste segment offers flavor compounds primarily to the food and beverage industries for use in consumer products, such as prepared foods, beverages, dairy, food, and sweet products. This segment also creates and manufactures a naturals-focused suite of flavor compounds, functional foods, and specialty fine ingredients to small, local, and regional customers. The Scent segment provides fragrance compounds, which include fine fragrances comprising perfumes and colognes, as well as consumer fragrances for personal care, household products, and beauty care; fragrance ingredients comprising synthetic and natural ingredients that could be combined with other materials to create fragrance and consumer compounds; and cosmetic active ingredients consisting of active and functional ingredients, botanicals, and delivery systems to support its customers' cosmetic and personal care product lines. This segment serves perfume and toiletries manufacturers in the cosmetics industry; and manufacturers of soaps, detergents, fabric care, household cleaners, and air fresheners in the household products industry. The company has operations in Europe, Africa, the Middle East, Greater Asia, North America, and Latin America. International Flavors & Fragrances Inc. was founded in 1833 and is headquartered in New York, New York.
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    International Paper Company operates as a paper and packaging company primarily in United States, the Middle East, Europe, Africa, Pacific Rim, Asia, and the Americas. It operates through three segments: Industrial Packaging, Global Cellulose Fibers, and Printing Papers. The Industrial Packaging segment manufactures containerboards, including linerboard, medium, whitetop, recycled linerboard, recycled medium, and saturating Kraft. The Global Cellulose Fibers segment provides fluff, market, and specialty pulps that are used in absorbent hygiene products, such as baby diapers, feminine care, adult incontinence and other non-woven products; tissue and paper products; and non-absorbent end applications, including textiles, filtration, construction material, paints and coatings, reinforced plastics and more. The Printing Papers segment produces printing and writing papers, such as uncoated papers for end-use applications comprising brochures, pamphlets, greeting cards, books, annual reports, and direct mail, as well as envelopes, tablets, business forms, and file folders. It sells its uncoated papers under the Hammermill, Springhill, Williamsburg, Postmark, Accent, Great White, Chamex, Ballet, Rey, Pol, and Svetocopy brands. The company sells its products directly to end users and converters, as well as through agents, resellers, and paper distributors. International Paper Company was founded in 1898 and is headquartered in Memphis, Tennessee.
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Intrepid Potash, Inc., together with its subsidiaries, engages in the extraction and production of the potash in the United States and internationally. It operates through three segments: Potash, Trio, and Oilfield Solutions. The Potash segment offers muriate of potash or potassium chloride for use as a fertilizer input in the agricultural market; as a component in drilling and fracturing fluids for oil and gas wells, as well as an input to other industrial processes in the industrial market; and as a nutrient supplement in the animal feed market. The Trio segment provides Trio, a specialty fertilizer that delivers potassium, sulfate, and magnesium in a single particle. The Oilfield Solutions segment sells water for use in the oil and gas services industry; and offers potassium chloride real-time mixing services on location for hydraulic fracturing operations and trucking services. The company also offers salt for use in animal feeds, industrial applications, pool salts, and treatment of roads and walkways for ice melting or to manage road conditions; magnesium chloride for use in the deicing and dedusting of roads; brines for well development and completion activities in the oil and gas industry; and metal recovery salt, a combination of potash and salt to enhance the recovery of aluminum in the aluminum recycling processing facilities. Intrepid Potash, Inc. was founded in 2000 and is based in Denver, Colorado.
# 8                                                                                                                                                                                                                                                                                                                                                                      Israel Corporation Ltd, together with its subsidiaries, engages in the specialty minerals and chemicals, and refining and petrochemicals businesses in Israel, Europe, North America, Asia, South America, and internationally. It extracts raw materials, including potash and bromine from Dead Sea; and specialty phosphates from phosphate rock mines. The company offers bromine-based flame retardants and industrial solutions; elemental bromine; bromine compounds; magnesium; phosphorous-based industrial compounds; specialty agriculture products; phosphate fertilizers; green phosphoric acid; phosphorus-based flame retardants; clear brine fluids; calcium products; brominated biocides; organic and inorganic bromides; potassium chloride; magnesium dichloride; and magnesia products. It also provide specialty fertilizers, including soluble fertilizers, which includes water-soluble straights and water-soluble NPK; controlled release fertilizers; and liquid NPK fertilizers. In addition, the company produces fuel products; raw materials for the petrochemical industry; materials for the plastics industry; and oils, waxes, and related products, as well as provides power and water, including steam services to various industries in Haifa. Its products are primarily used in the areas of agriculture, electronics, construction, automotive, oil drilling, food, furniture, pharmaceutical, textile, water treatment, metal treatment, oral care, carbonated drinks, asphalt modification, paints and coatings, and other industries. The company was founded in 1968 and is based in Tel Aviv, Israel.
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Ivanhoe Mines Ltd. engages in the exploration, development, and recovery of minerals and precious metals located primarily in Africa. The company explores for platinum, palladium, nickel, copper, gold, rhodium, zinc, germanium, and lead deposits. Its projects include the Platreef project located in the Northern Limb of South Africa's Bushveld Complex; the Kipushi project located on the DRC's Copperbelt; and the Kamoa-Kakula project located within the Central African Copperbelt. It also holds a 100% interest in the Western Foreland exploration project covering an area of approximately 2,550 square kilometers located in the Democratic Republic of Congo. The company was formerly known as Ivanplats Limited and changed its name to Ivanhoe Mines Ltd. in August 2013. Ivanhoe Mines Ltd. was incorporated in 1993 and is headquartered in Vancouver, Canada.
#
#    gicSector                                url  \
# 0  Materials      https://www.hycroftmining.com
# 1  Materials           http://www.icl-group.com
# 2  Materials    http://www.indoramaventures.com
# 3  Materials            http://www.ingevity.com
# 4  Materials         http://www.innospecinc.com
# 5  Materials                 http://www.iff.com
# 6  Materials  http://www.internationalpaper.com
# 7  Materials     https://www.intrepidpotash.com
# 8  Materials          http://www.israelcorp.com
# 9  Materials        http://www.ivanhoemines.com
#
#                                                             address  \
# 0                      Unit 1, Winnemucca, NV, United States, 89445
# 1                          Millenium Tower, Tel Aviv, Israel, 61070
# 2                   75/102, Ocean Tower 2, Bangkok, Thailand, 10110
# 3  5255 Virginia Avenue, North Charleston, SC, United States, 29406
# 4    8310 South Valley Highway, Englewood, CO, United States, 80112
# 5          521 West 57th Street, New York, NY, United States, 10019
# 6             6400 Poplar Avenue, Memphis, TN, United States, 38197
# 7                1001 17th Street, Denver, CO, United States, 80202
# 8                         Millennium Tower, Tel Aviv, Israel, 61204
# 9                  999 Canada Place, Vancouver, BC, Canada, V6C 3E1
#
#                          gicSubIndustry  company_pulse  \
# 0                                  Gold      -0.089544
# 1  Fertilizers & Agricultural Chemicals       0.473901
# 2                   Commodity Chemicals       0.365546
# 3                   Specialty Chemicals       0.460788
# 4                   Specialty Chemicals       0.800200
# 5                   Specialty Chemicals       0.279332
# 6                       Paper Packaging       0.258956
# 7  Fertilizers & Agricultural Chemicals       0.510600
# 8  Fertilizers & Agricultural Chemicals       0.000000
# 9           Diversified Metals & Mining       0.317213
#
#                                                                                    pos_neg_ratio  \
# 0       [{'sentiment_rank': 'negative', 'total': 7}, {'sentiment_rank': 'positive', 'total': 9}]
# 1      [{'sentiment_rank': 'negative', 'total': 7}, {'sentiment_rank': 'positive', 'total': 78}]
# 2      [{'sentiment_rank': 'negative', 'total': 5}, {'sentiment_rank': 'positive', 'total': 24}]
# 3      [{'sentiment_rank': 'negative', 'total': 6}, {'sentiment_rank': 'positive', 'total': 40}]
# 4                                                   [{'sentiment_rank': 'positive', 'total': 4}]
# 5    [{'sentiment_rank': 'negative', 'total': 62}, {'sentiment_rank': 'positive', 'total': 228}]
# 6  [{'sentiment_rank': 'negative', 'total': 230}, {'sentiment_rank': 'positive', 'total': 1136}]
# 7                                                   [{'sentiment_rank': 'positive', 'total': 1}]
# 8                                                   [{'sentiment_rank': 'positive', 'total': 2}]
# 9      [{'sentiment_rank': 'negative', 'total': 3}, {'sentiment_rank': 'positive', 'total': 11}]
#
#    esg_beta  \
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5  0.232317
# 6  0.183925
# 7       NaN
# 8       NaN
# 9       NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# ...
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...

# %%
df_detail2.columns
# Out:
# Index(['id', 'company_name', 'description', 'gicSector', 'url', 'address',
#        'gicSubIndustry', 'company_pulse', 'pos_neg_ratio', 'esg_beta',
#        'esg_beta_tseries'],
#       dtype='object')

# %%
# drop unnecessary columns
df_detail = df_detail2.drop(columns=['description', 'url', 'pos_neg_ratio', 'esg_beta_tseries'])
df_detail
# Out:
#        id                              company_name  gicSector  \
# 0  243688        Hycroft Mining Holding Corporation  Materials
# 1  194060                             ICL Group Ltd  Materials
# 2  202406  Indorama Ventures Public Company Limited  Materials
# 3  206642                      Ingevity Corporation  Materials
# 4  206404                              Innospec Inc  Materials
# 5  189956    International Flavors & Fragrances Inc  Materials
# 6  190398               International Paper Company  Materials
# 7  245305                       Intrepid Potash Inc  Materials
# 8  194047                    Israel Corporation Ltd  Materials
# 9  206013                         Ivanhoe Mines Ltd  Materials
#
#                                                             address  \
# 0                      Unit 1, Winnemucca, NV, United States, 89445
# 1                          Millenium Tower, Tel Aviv, Israel, 61070
# 2                   75/102, Ocean Tower 2, Bangkok, Thailand, 10110
# 3  5255 Virginia Avenue, North Charleston, SC, United States, 29406
# 4    8310 South Valley Highway, Englewood, CO, United States, 80112
# 5          521 West 57th Street, New York, NY, United States, 10019
# 6             6400 Poplar Avenue, Memphis, TN, United States, 38197
# 7                1001 17th Street, Denver, CO, United States, 80202
# 8                         Millennium Tower, Tel Aviv, Israel, 61204
# 9                  999 Canada Place, Vancouver, BC, Canada, V6C 3E1
#
#                          gicSubIndustry  company_pulse  esg_beta
# 0                                  Gold      -0.089544       NaN
# 1  Fertilizers & Agricultural Chemicals       0.473901       NaN
# 2                   Commodity Chemicals       0.365546       NaN
# 3                   Specialty Chemicals       0.460788       NaN
# 4                   Specialty Chemicals       0.800200       NaN
# 5                   Specialty Chemicals       0.279332  0.232317
# 6                       Paper Packaging       0.258956  0.183925
# 7  Fertilizers & Agricultural Chemicals       0.510600       NaN
# 8  Fertilizers & Agricultural Chemicals       0.000000       NaN
# 9           Diversified Metals & Mining       0.317213       NaN

# %%
# sort by company name & will use later when joining with next df bc there are no common columns; use ignore_index=True to reset index & keep new index while discarding old one
df_detail_F = df_detail.sort_values(by=["company_name"],ignore_index=True)
df_detail_F
# Out:
#        id                              company_name  gicSector  \
# 0  243688        Hycroft Mining Holding Corporation  Materials
# 1  194060                             ICL Group Ltd  Materials
# 2  202406  Indorama Ventures Public Company Limited  Materials
# 3  206642                      Ingevity Corporation  Materials
# 4  206404                              Innospec Inc  Materials
# 5  189956    International Flavors & Fragrances Inc  Materials
# 6  190398               International Paper Company  Materials
# 7  245305                       Intrepid Potash Inc  Materials
# 8  194047                    Israel Corporation Ltd  Materials
# 9  206013                         Ivanhoe Mines Ltd  Materials
#
#                                                             address  \
# 0                      Unit 1, Winnemucca, NV, United States, 89445
# 1                          Millenium Tower, Tel Aviv, Israel, 61070
# 2                   75/102, Ocean Tower 2, Bangkok, Thailand, 10110
# 3  5255 Virginia Avenue, North Charleston, SC, United States, 29406
# 4    8310 South Valley Highway, Englewood, CO, United States, 80112
# 5          521 West 57th Street, New York, NY, United States, 10019
# 6             6400 Poplar Avenue, Memphis, TN, United States, 38197
# 7                1001 17th Street, Denver, CO, United States, 80202
# 8                         Millennium Tower, Tel Aviv, Israel, 61204
# 9                  999 Canada Place, Vancouver, BC, Canada, V6C 3E1
#
#                          gicSubIndustry  company_pulse  esg_beta
# 0                                  Gold      -0.089544       NaN
# 1  Fertilizers & Agricultural Chemicals       0.473901       NaN
# 2                   Commodity Chemicals       0.365546       NaN
# 3                   Specialty Chemicals       0.460788       NaN
# 4                   Specialty Chemicals       0.800200       NaN
# 5                   Specialty Chemicals       0.279332  0.232317
# 6                       Paper Packaging       0.258956  0.183925
# 7  Fertilizers & Agricultural Chemicals       0.510600       NaN
# 8  Fertilizers & Agricultural Chemicals       0.000000       NaN
# 9           Diversified Metals & Mining       0.317213       NaN

# %%
df_detail_F.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              10 non-null     int64
#  1   company_name    10 non-null     object
#  2   gicSector       10 non-null     object
#  3   address         10 non-null     object
#  4   gicSubIndustry  10 non-null     object
#  5   company_pulse   10 non-null     float64
#  6   esg_beta        2 non-null      float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 688.0+ bytes

# %%
df_securities = pd.json_normalize(dict_data, 'securities')
df_securities
# Out:
#                    exchange  exchange_id   code          isin      cusip  \
# 0           NASDAQ Exchnage           75   HYMC  US44862P1093         NA
# 1   New York Stock Exchange           69    ICL  US4650471083  465036200
# 2         Tel Aviv Exchange           32    ICL  IL0002810146
# 3                      Pink           72  INDOY
# 4        Frankfurt Exchange           12    I93
# 5         Thailand Exchange           44    IVL  TH1027010004
# 6   New York Stock Exchange           69   NGVT  US45688C1071  45688C107
# 7        Frankfurt Exchange           12    IGX  US45688C1071         NA
# 8           NASDAQ Exchnage           75   IOSP  US45768S1050  45768S105
# 9        Frankfurt Exchange           12    OCT
# 10          NASDAQ Exchnage           75   IOSP  US45768S1050  675727101
# 11       Frankfurt Exchange           12    OCT  US45768S1050         NA
# 12  New York Stock Exchange           69    IFF  US4595061015  459506101
# 13       Frankfurt Exchange           12    IFF
# 14        Tel Aviv Exchange           32    IFF
# 15  New York Stock Exchange           69    IFF  US4595061015  459506101
# 16       Frankfurt Exchange           12    IFF  US4595061015         NA
# 17  New York Stock Exchange           69     IP  US4601461035  460146103
# 18           XETRA Exchange            7    INP
# 19       Frankfurt Exchange           12    INP
# 20         Mexican Exchange           54     IP
# 21           XETRA Exchange            7    INP  US4601461035         NA
# 22  New York Stock Exchange           69    IPI  US46121Y2019  46121Y102
# 23       Frankfurt Exchange           12   58I1  US46121Y2019         NA
# 24                     Pink           72  IRLCF
# 25        Tel Aviv Exchange           32   ILCO  IL0005760173
# 26          OTC QX Exchange           78  IVPAF
# 27         Toronto Exchange            3    IVN  CA46579R1047
# 28       Frankfurt Exchange           12   IYAA
#
#    securities_type currency_code
# 0     Common Stock           USD
# 1     Common Stock           USD
# 2     Common Stock           ILS
# 3     Common Stock           USD
# 4     Common Stock           EUR
# 5     Common Stock           THB
# 6     Common Stock           USD
# 7     Common Stock           EUR
# 8     Common Stock           USD
# 9     Common Stock           EUR
# 10    Common Stock           USD
# 11    Common Stock           EUR
# 12    Common Stock           USD
# 13    Common Stock           EUR
# 14    Common Stock           ILS
# 15    Common Stock           USD
# 16    Common Stock           EUR
# 17    Common Stock           USD
# 18    Common Stock           EUR
# 19    Common Stock           EUR
# 20    Common Stock           MXN
# 21    Common Stock           EUR
# 22    Common Stock           USD
# 23    Common Stock           EUR
# 24    Common Stock           USD
# 25    Common Stock           ILS
# 26    Common Stock           USD
# 27    Common Stock           CAD
# 28    Common Stock           EUR

# %%
df_securities["exchange"].value_counts()
# Out:
# exchange
# Frankfurt Exchange         9
# New York Stock Exchange    6
#  NASDAQ Exchnage           3
# Tel Aviv Exchange          3
#  Pink                      2
# XETRA Exchange             2
# Thailand Exchange          1
# Mexican Exchange           1
#  OTC QX Exchange           1
# Toronto Exchange           1
# Name: count, dtype: int64

# %%
exchanges = ['New York Stock Exchange', "NASDAQ Exchnage"]

mask = df_securities['exchange'].isin
df_securities_US = df_securities.loc[df_securities['currency_code'] == "USD"]
df_securities_US.head(10)
# Out:
#                    exchange  exchange_id   code          isin      cusip  \
# 0           NASDAQ Exchnage           75   HYMC  US44862P1093         NA
# 1   New York Stock Exchange           69    ICL  US4650471083  465036200
# 3                      Pink           72  INDOY
# 6   New York Stock Exchange           69   NGVT  US45688C1071  45688C107
# 8           NASDAQ Exchnage           75   IOSP  US45768S1050  45768S105
# 10          NASDAQ Exchnage           75   IOSP  US45768S1050  675727101
# 12  New York Stock Exchange           69    IFF  US4595061015  459506101
# 15  New York Stock Exchange           69    IFF  US4595061015  459506101
# 17  New York Stock Exchange           69     IP  US4601461035  460146103
# 22  New York Stock Exchange           69    IPI  US46121Y2019  46121Y102
#
#    securities_type currency_code
# 0     Common Stock           USD
# 1     Common Stock           USD
# 3     Common Stock           USD
# 6     Common Stock           USD
# 8     Common Stock           USD
# 10    Common Stock           USD
# 12    Common Stock           USD
# 15    Common Stock           USD
# 17    Common Stock           USD
# 22    Common Stock           USD

# %%
# select any duplicate rows 
dupes = df_securities_US[df_securities_US.duplicated("code")]
dupes
# Out:
#                    exchange  exchange_id  code          isin      cusip  \
# 10          NASDAQ Exchnage           75  IOSP  US45768S1050  675727101
# 15  New York Stock Exchange           69   IFF  US4595061015  459506101
#
#    securities_type currency_code
# 10    Common Stock           USD
# 15    Common Stock           USD

# %%
# drop duplicate rows
securities_final2= df_securities_US.drop_duplicates("code")
securities_final2
# Out:
#                    exchange  exchange_id   code          isin      cusip  \
# 0           NASDAQ Exchnage           75   HYMC  US44862P1093         NA
# 1   New York Stock Exchange           69    ICL  US4650471083  465036200
# 3                      Pink           72  INDOY
# 6   New York Stock Exchange           69   NGVT  US45688C1071  45688C107
# 8           NASDAQ Exchnage           75   IOSP  US45768S1050  45768S105
# 12  New York Stock Exchange           69    IFF  US4595061015  459506101
# 17  New York Stock Exchange           69     IP  US4601461035  460146103
# 22  New York Stock Exchange           69    IPI  US46121Y2019  46121Y102
# 24                     Pink           72  IRLCF
# 26          OTC QX Exchange           78  IVPAF
#
#    securities_type currency_code
# 0     Common Stock           USD
# 1     Common Stock           USD
# 3     Common Stock           USD
# 6     Common Stock           USD
# 8     Common Stock           USD
# 12    Common Stock           USD
# 17    Common Stock           USD
# 22    Common Stock           USD
# 24    Common Stock           USD
# 26    Common Stock           USD

# %%
securities_final = securities_final2.sort_values(by=["code"], ignore_index=True)
securities_final
# Out:
#                   exchange  exchange_id   code          isin      cusip  \
# 0          NASDAQ Exchnage           75   HYMC  US44862P1093         NA
# 1  New York Stock Exchange           69    ICL  US4650471083  465036200
# 2  New York Stock Exchange           69    IFF  US4595061015  459506101
# 3                     Pink           72  INDOY
# 4          NASDAQ Exchnage           75   IOSP  US45768S1050  45768S105
# 5  New York Stock Exchange           69     IP  US4601461035  460146103
# 6  New York Stock Exchange           69    IPI  US46121Y2019  46121Y102
# 7                     Pink           72  IRLCF
# 8          OTC QX Exchange           78  IVPAF
# 9  New York Stock Exchange           69   NGVT  US45688C1071  45688C107
#
#   securities_type currency_code
# 0    Common Stock           USD
# 1    Common Stock           USD
# 2    Common Stock           USD
# 3    Common Stock           USD
# 4    Common Stock           USD
# 5    Common Stock           USD
# 6    Common Stock           USD
# 7    Common Stock           USD
# 8    Common Stock           USD
# 9    Common Stock           USD

# %%
# merge the df that has company details with the df that has securities info; see https://www.statology.org/pandas-merge-on-index/

df_merged = pd.merge(df_detail_F, securities_final, left_index=True, right_index=True)
df_merged
# Out:
#        id                              company_name  gicSector  \
# 0  243688        Hycroft Mining Holding Corporation  Materials
# 1  194060                             ICL Group Ltd  Materials
# 2  202406  Indorama Ventures Public Company Limited  Materials
# 3  206642                      Ingevity Corporation  Materials
# 4  206404                              Innospec Inc  Materials
# 5  189956    International Flavors & Fragrances Inc  Materials
# 6  190398               International Paper Company  Materials
# 7  245305                       Intrepid Potash Inc  Materials
# 8  194047                    Israel Corporation Ltd  Materials
# 9  206013                         Ivanhoe Mines Ltd  Materials
#
#                                                             address  \
# 0                      Unit 1, Winnemucca, NV, United States, 89445
# 1                          Millenium Tower, Tel Aviv, Israel, 61070
# 2                   75/102, Ocean Tower 2, Bangkok, Thailand, 10110
# 3  5255 Virginia Avenue, North Charleston, SC, United States, 29406
# 4    8310 South Valley Highway, Englewood, CO, United States, 80112
# 5          521 West 57th Street, New York, NY, United States, 10019
# 6             6400 Poplar Avenue, Memphis, TN, United States, 38197
# 7                1001 17th Street, Denver, CO, United States, 80202
# 8                         Millennium Tower, Tel Aviv, Israel, 61204
# 9                  999 Canada Place, Vancouver, BC, Canada, V6C 3E1
#
#                          gicSubIndustry  company_pulse  esg_beta  \
# 0                                  Gold      -0.089544       NaN
# 1  Fertilizers & Agricultural Chemicals       0.473901       NaN
# 2                   Commodity Chemicals       0.365546       NaN
# 3                   Specialty Chemicals       0.460788       NaN
# 4                   Specialty Chemicals       0.800200       NaN
# 5                   Specialty Chemicals       0.279332  0.232317
# 6                       Paper Packaging       0.258956  0.183925
# 7  Fertilizers & Agricultural Chemicals       0.510600       NaN
# 8  Fertilizers & Agricultural Chemicals       0.000000       NaN
# 9           Diversified Metals & Mining       0.317213       NaN
#
#                   exchange  exchange_id   code          isin      cusip  \
# 0          NASDAQ Exchnage           75   HYMC  US44862P1093         NA
# 1  New York Stock Exchange           69    ICL  US4650471083  465036200
# 2  New York Stock Exchange           69    IFF  US4595061015  459506101
# 3                     Pink           72  INDOY
# 4          NASDAQ Exchnage           75   IOSP  US45768S1050  45768S105
# 5  New York Stock Exchange           69     IP  US4601461035  460146103
# 6  New York Stock Exchange           69    IPI  US46121Y2019  46121Y102
# 7                     Pink           72  IRLCF
# 8          OTC QX Exchange           78  IVPAF
# 9  New York Stock Exchange           69   NGVT  US45688C1071  45688C107
#
#   securities_type currency_code
# 0    Common Stock           USD
# 1    Common Stock           USD
# 2    Common Stock           USD
# 3    Common Stock           USD
# 4    Common Stock           USD
# 5    Common Stock           USD
# 6    Common Stock           USD
# 7    Common Stock           USD
# 8    Common Stock           USD
# 9    Common Stock           USD

# %%
df_merged[["street_address", "City", "State", "Country", "zip"]] = df_merged["address"].str.split(",", expand=True)
df_merged
# Out:
#        id                              company_name  gicSector  \
# 0  243688        Hycroft Mining Holding Corporation  Materials
# 1  194060                             ICL Group Ltd  Materials
# 2  202406  Indorama Ventures Public Company Limited  Materials
# 3  206642                      Ingevity Corporation  Materials
# 4  206404                              Innospec Inc  Materials
# 5  189956    International Flavors & Fragrances Inc  Materials
# 6  190398               International Paper Company  Materials
# 7  245305                       Intrepid Potash Inc  Materials
# 8  194047                    Israel Corporation Ltd  Materials
# 9  206013                         Ivanhoe Mines Ltd  Materials
#
#                                                             address  \
# 0                      Unit 1, Winnemucca, NV, United States, 89445
# 1                          Millenium Tower, Tel Aviv, Israel, 61070
# 2                   75/102, Ocean Tower 2, Bangkok, Thailand, 10110
# 3  5255 Virginia Avenue, North Charleston, SC, United States, 29406
# 4    8310 South Valley Highway, Englewood, CO, United States, 80112
# 5          521 West 57th Street, New York, NY, United States, 10019
# 6             6400 Poplar Avenue, Memphis, TN, United States, 38197
# 7                1001 17th Street, Denver, CO, United States, 80202
# 8                         Millennium Tower, Tel Aviv, Israel, 61204
# 9                  999 Canada Place, Vancouver, BC, Canada, V6C 3E1
#
#                          gicSubIndustry  company_pulse  esg_beta  \
# 0                                  Gold      -0.089544       NaN
# 1  Fertilizers & Agricultural Chemicals       0.473901       NaN
# 2                   Commodity Chemicals       0.365546       NaN
# 3                   Specialty Chemicals       0.460788       NaN
# 4                   Specialty Chemicals       0.800200       NaN
# 5                   Specialty Chemicals       0.279332  0.232317
# 6                       Paper Packaging       0.258956  0.183925
# 7  Fertilizers & Agricultural Chemicals       0.510600       NaN
# 8  Fertilizers & Agricultural Chemicals       0.000000       NaN
# 9           Diversified Metals & Mining       0.317213       NaN
#
#                   exchange  exchange_id   code          isin      cusip  \
# 0          NASDAQ Exchnage           75   HYMC  US44862P1093         NA
# 1  New York Stock Exchange           69    ICL  US4650471083  465036200
# 2  New York Stock Exchange           69    IFF  US4595061015  459506101
# 3                     Pink           72  INDOY
# 4          NASDAQ Exchnage           75   IOSP  US45768S1050  45768S105
# 5  New York Stock Exchange           69     IP  US4601461035  460146103
# 6  New York Stock Exchange           69    IPI  US46121Y2019  46121Y102
# 7                     Pink           72  IRLCF
# 8          OTC QX Exchange           78  IVPAF
# 9  New York Stock Exchange           69   NGVT  US45688C1071  45688C107
#
#   securities_type currency_code             street_address               City  \
# 0    Common Stock           USD                     Unit 1         Winnemucca
# 1    Common Stock           USD            Millenium Tower           Tel Aviv
# 2    Common Stock           USD                     75/102      Ocean Tower 2
# 3    Common Stock           USD       5255 Virginia Avenue   North Charleston
# 4    Common Stock           USD  8310 South Valley Highway          Englewood
# 5    Common Stock           USD       521 West 57th Street           New York
# 6    Common Stock           USD         6400 Poplar Avenue            Memphis
# 7    Common Stock           USD           1001 17th Street             Denver
# 8    Common Stock           USD           Millennium Tower           Tel Aviv
# 9    Common Stock           USD           999 Canada Place          Vancouver
#
#       State         Country       zip
# 0        NV   United States     89445
# 1    Israel           61070      None
# 2   Bangkok        Thailand     10110
# 3        SC   United States     29406
# 4        CO   United States     80112
# 5        NY   United States     10019
# 6        TN   United States     38197
# 7        CO   United States     80202
# 8    Israel           61204      None
# 9        BC          Canada   V6C 3E1

# %%
df_merged.columns
# Out:
# Index(['id', 'company_name', 'gicSector', 'address', 'gicSubIndustry',
#        'company_pulse', 'esg_beta', 'exchange', 'exchange_id', 'code', 'isin',
#        'cusip', 'securities_type', 'currency_code', 'street_address', 'City',
#        'State', 'Country', 'zip'],
#       dtype='object')

# %%
df_merged_temp = df_merged.rename(columns={'code': "symbol",
                                           'id': 'unique_id'
                                        })
df_merged_temp
# Out:
#    unique_id                              company_name  gicSector  \
# 0     243688        Hycroft Mining Holding Corporation  Materials
# 1     194060                             ICL Group Ltd  Materials
# 2     202406  Indorama Ventures Public Company Limited  Materials
# 3     206642                      Ingevity Corporation  Materials
# 4     206404                              Innospec Inc  Materials
# 5     189956    International Flavors & Fragrances Inc  Materials
# 6     190398               International Paper Company  Materials
# 7     245305                       Intrepid Potash Inc  Materials
# 8     194047                    Israel Corporation Ltd  Materials
# 9     206013                         Ivanhoe Mines Ltd  Materials
#
#                                                             address  \
# 0                      Unit 1, Winnemucca, NV, United States, 89445
# 1                          Millenium Tower, Tel Aviv, Israel, 61070
# 2                   75/102, Ocean Tower 2, Bangkok, Thailand, 10110
# 3  5255 Virginia Avenue, North Charleston, SC, United States, 29406
# 4    8310 South Valley Highway, Englewood, CO, United States, 80112
# 5          521 West 57th Street, New York, NY, United States, 10019
# 6             6400 Poplar Avenue, Memphis, TN, United States, 38197
# 7                1001 17th Street, Denver, CO, United States, 80202
# 8                         Millennium Tower, Tel Aviv, Israel, 61204
# 9                  999 Canada Place, Vancouver, BC, Canada, V6C 3E1
#
#                          gicSubIndustry  company_pulse  esg_beta  \
# 0                                  Gold      -0.089544       NaN
# 1  Fertilizers & Agricultural Chemicals       0.473901       NaN
# 2                   Commodity Chemicals       0.365546       NaN
# 3                   Specialty Chemicals       0.460788       NaN
# 4                   Specialty Chemicals       0.800200       NaN
# 5                   Specialty Chemicals       0.279332  0.232317
# 6                       Paper Packaging       0.258956  0.183925
# 7  Fertilizers & Agricultural Chemicals       0.510600       NaN
# 8  Fertilizers & Agricultural Chemicals       0.000000       NaN
# 9           Diversified Metals & Mining       0.317213       NaN
#
#                   exchange  exchange_id symbol          isin      cusip  \
# 0          NASDAQ Exchnage           75   HYMC  US44862P1093         NA
# 1  New York Stock Exchange           69    ICL  US4650471083  465036200
# 2  New York Stock Exchange           69    IFF  US4595061015  459506101
# 3                     Pink           72  INDOY
# 4          NASDAQ Exchnage           75   IOSP  US45768S1050  45768S105
# 5  New York Stock Exchange           69     IP  US4601461035  460146103
# 6  New York Stock Exchange           69    IPI  US46121Y2019  46121Y102
# 7                     Pink           72  IRLCF
# 8          OTC QX Exchange           78  IVPAF
# 9  New York Stock Exchange           69   NGVT  US45688C1071  45688C107
#
#   securities_type currency_code             street_address               City  \
# 0    Common Stock           USD                     Unit 1         Winnemucca
# 1    Common Stock           USD            Millenium Tower           Tel Aviv
# 2    Common Stock           USD                     75/102      Ocean Tower 2
# 3    Common Stock           USD       5255 Virginia Avenue   North Charleston
# 4    Common Stock           USD  8310 South Valley Highway          Englewood
# 5    Common Stock           USD       521 West 57th Street           New York
# 6    Common Stock           USD         6400 Poplar Avenue            Memphis
# 7    Common Stock           USD           1001 17th Street             Denver
# 8    Common Stock           USD           Millennium Tower           Tel Aviv
# 9    Common Stock           USD           999 Canada Place          Vancouver
#
#       State         Country       zip
# 0        NV   United States     89445
# 1    Israel           61070      None
# 2   Bangkok        Thailand     10110
# 3        SC   United States     29406
# 4        CO   United States     80112
# 5        NY   United States     10019
# 6        TN   United States     38197
# 7        CO   United States     80202
# 8    Israel           61204      None
# 9        BC          Canada   V6C 3E1

# %%
df_merged_temp.columns
# Out:
# Index(['unique_id', 'company_name', 'gicSector', 'address', 'gicSubIndustry',
#        'company_pulse', 'esg_beta', 'exchange', 'exchange_id', 'symbol',
#        'isin', 'cusip', 'securities_type', 'currency_code', 'street_address',
#        'City', 'State', 'Country', 'zip'],
#       dtype='object')

# %%
# reorder the columns so that they match other datasets
df_details_secur = df_merged_temp[['unique_id', 'company_name', 'gicSector', 'gicSubIndustry','company_pulse', 
        'esg_beta', 'City', 'State', 'Country','zip','exchange', 'symbol', 'isin',
       'cusip', 'securities_type', 'currency_code']]

df_details_secur
# Out:
#    unique_id                              company_name  gicSector  \
# 0     243688        Hycroft Mining Holding Corporation  Materials
# 1     194060                             ICL Group Ltd  Materials
# 2     202406  Indorama Ventures Public Company Limited  Materials
# 3     206642                      Ingevity Corporation  Materials
# 4     206404                              Innospec Inc  Materials
# 5     189956    International Flavors & Fragrances Inc  Materials
# 6     190398               International Paper Company  Materials
# 7     245305                       Intrepid Potash Inc  Materials
# 8     194047                    Israel Corporation Ltd  Materials
# 9     206013                         Ivanhoe Mines Ltd  Materials
#
#                          gicSubIndustry  company_pulse  esg_beta  \
# 0                                  Gold      -0.089544       NaN
# 1  Fertilizers & Agricultural Chemicals       0.473901       NaN
# 2                   Commodity Chemicals       0.365546       NaN
# 3                   Specialty Chemicals       0.460788       NaN
# 4                   Specialty Chemicals       0.800200       NaN
# 5                   Specialty Chemicals       0.279332  0.232317
# 6                       Paper Packaging       0.258956  0.183925
# 7  Fertilizers & Agricultural Chemicals       0.510600       NaN
# 8  Fertilizers & Agricultural Chemicals       0.000000       NaN
# 9           Diversified Metals & Mining       0.317213       NaN
#
#                 City     State         Country       zip  \
# 0         Winnemucca        NV   United States     89445
# 1           Tel Aviv    Israel           61070      None
# 2      Ocean Tower 2   Bangkok        Thailand     10110
# 3   North Charleston        SC   United States     29406
# 4          Englewood        CO   United States     80112
# 5           New York        NY   United States     10019
# 6            Memphis        TN   United States     38197
# 7             Denver        CO   United States     80202
# 8           Tel Aviv    Israel           61204      None
# 9          Vancouver        BC          Canada   V6C 3E1
#
#                   exchange symbol          isin      cusip securities_type  \
# 0          NASDAQ Exchnage   HYMC  US44862P1093         NA    Common Stock
# 1  New York Stock Exchange    ICL  US4650471083  465036200    Common Stock
# 2  New York Stock Exchange    IFF  US4595061015  459506101    Common Stock
# 3                     Pink  INDOY                             Common Stock
# 4          NASDAQ Exchnage   IOSP  US45768S1050  45768S105    Common Stock
# 5  New York Stock Exchange     IP  US4601461035  460146103    Common Stock
# 6  New York Stock Exchange    IPI  US46121Y2019  46121Y102    Common Stock
# 7                     Pink  IRLCF                             Common Stock
# 8          OTC QX Exchange  IVPAF                             Common Stock
# 9  New York Stock Exchange   NGVT  US45688C1071  45688C107    Common Stock
#
#   currency_code
# 0           USD
# 1           USD
# 2           USD
# 3           USD
# 4           USD
# 5           USD
# 6           USD
# 7           USD
# 8           USD
# 9           USD

# %%
df_details_secur.dtypes
# Out:
# unique_id            int64
# company_name        object
# gicSector           object
# gicSubIndustry      object
# company_pulse      float64
# esg_beta           float64
# City                object
# State               object
# Country             object
# zip                 object
# exchange            object
# symbol              object
# isin                object
# cusip               object
# securities_type     object
# currency_code       object
# dtype: object

# %%
convert = {"unique_id": str
          }
df_final = df_details_secur.astype(convert)
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   unique_id        10 non-null     object
#  1   company_name     10 non-null     object
#  2   gicSector        10 non-null     object
#  3   gicSubIndustry   10 non-null     object
#  4   company_pulse    10 non-null     float64
#  5   esg_beta         2 non-null      float64
#  6   City             10 non-null     object
#  7   State            10 non-null     object
#  8   Country          10 non-null     object
#  9   zip              8 non-null      object
#  10  exchange         10 non-null     object
#  11  symbol           10 non-null     object
#  12  isin             10 non-null     object
#  13  cusip            10 non-null     object
#  14  securities_type  10 non-null     object
#  15  currency_code    10 non-null     object
# dtypes: float64(2), object(14)
# memory usage: 1.4+ KB

# %%
# Check to see how many unique company names there are in our results
df_final.company_name.nunique(dropna=True)
# Out:
# 10

# %%
# Export file as a CSV, without the Pandas index, but with the header
df_final.to_csv("materials11.csv", index = False, header=True)
